# %% [markdown]
# ### BetFair API Guide
# https://towardsdatascience.com/an-introduction-to-betfair-api-and-how-to-use-it-e3cdbd79c94b#:~:text=To%20begin%20you%20will%20need,click%20and%20select%20Inspect%20Element.

# %%
import json
import datetime
import urllib
import urllib.request
import urllib.error
import requests
import pandas as pd

# %% [markdown]
# login using requests.post() to get the SSOID

# %%
path_creds = './../certs/credentials.json'
path_cert = './../certs/default_app.crt'
path_key = './../certs/bf_key_rsa.key'
path_data = './../data/'

with open(path_creds) as f:
    cred = json.load(f)
    my_username = cred['username']
    my_password = cred['password']
    my_app_key = cred['app_key']

payload = 'username=' + my_username + '&password=' + my_password
headers = {'X-Application': my_app_key, 'Content-Type': 'application/x-www-form-urlencoded'}
resp = requests.post('https://identitysso-cert.betfair.com/api/certlogin',data=payload,cert=(path_cert, path_key), headers=headers)
json_resp=resp.json()
SSOID = json_resp['sessionToken']

# %% [markdown]
# Here we are setting the URL that will be posting to, the request, and the headers. This particular request will provide a list of all available sports from Betfair. The URL below is set once and is the same URL that all requests are sent to. The event_req is the request that is being sent to the URL. This has to be set up like below bet can be changed when in this format. The method can be changed using the operations that can be found here. req retrieves the HTML response and is then converted into json to allow us to read it.
#
# eventypes is a list of dictionaries

# %%
bet_url="https://api.betfair.com/exchange/betting/json-rpc/v1"
event_req = '{"jsonrpc": "2.0", "method": "SportsAPING/v1.0/listEventTypes", "params": {"filter":{ }}, "id": 1}'
headers = {'X-Application': my_app_key, 'X-Authentication': SSOID, 'content-type': 'application/json'}
req = requests.post(bet_url, data=event_req.encode('utf-8'), headers=headers) 
eventTypes = req.json()
eventTypes
# Out:
# {'jsonrpc': '2.0',
#  'result': [{'eventType': {'id': '1', 'name': 'Soccer'}, 'marketCount': 8641},
#   {'eventType': {'id': '2', 'name': 'Tennis'}, 'marketCount': 2345},
#   {'eventType': {'id': '3', 'name': 'Golf'}, 'marketCount': 66},
#   {'eventType': {'id': '4', 'name': 'Cricket'}, 'marketCount': 119},
#   {'eventType': {'id': '1477', 'name': 'Rugby League'}, 'marketCount': 49},
#   {'eventType': {'id': '5', 'name': 'Rugby Union'}, 'marketCount': 28},
#   {'eventType': {'id': '6', 'name': 'Boxing'}, 'marketCount': 54},
#   {'eventType': {'id': '7', 'name': 'Horse Racing'}, 'marketCount': 695},
#   {'eventType': {'id': '8', 'name': 'Motor Sport'}, 'marketCount': 16},
#   {'eventType': {'id': '27454571', 'name': 'Esports'}, 'marketCount': 84},
#   {'eventType': {'id': '10', 'name': 'Special Bets'}, 'marketCount': 4},
#   {'eventType': {'id': '998917', 'name': 'Volleyball'}, 'marketCount': 6},
#   {'eventType': {'id': '11', 'name': 'Cycling'}, 'marketCount': 3},
#   {'eventType': {'id': '2152880', 'name': 'Gaelic Games'}, 'marketCount': 32},
#   {'eventType': {'id': '6422', 'name': 'Snooker'}, 'marketCount': 1},
#   {'eventType': {'id': '7511', 'name': 'Baseball'}, 'marketCount': 41},
#   {'eventType': {'id': '6423', 'name': 'American Football'},
#    'marketCount': 12},
#   {'eventType': {'id': '606611', 'name': 'Netball'}, 'marketCount': 4},
#   {'eventType': {'id': '7522', 'name': 'Basketball'}, 'marketCount': 52},
#   {'eventType': {'id': '61420', 'name': 'Australian Rules'},
#    'marketCount': 129},
#   {'eventType': {'id': '468328', 'name': 'Handball'}, 'marketCount': 6},
#   {'eventType': {'id': '3503', 'name': 'Darts'}, 'marketCount': 10},
#   {'eventType': {'id': '26420387', 'name': 'Mixed Martial Arts'},
#    'marketCount': 49},
#   {'eventType': {'id': '4339', 'name': 'Greyhound Racing'},
#    'marketCount': 809},
#   {'eventType': {'id': '2378961', 'name': 'Politics'}, 'marketCount': 36}],
#  'id': 1}

# %%
eventTypes['result']
# Out:
# [{'eventType': {'id': '1', 'name': 'Soccer'}, 'marketCount': 8641},
#  {'eventType': {'id': '2', 'name': 'Tennis'}, 'marketCount': 2345},
#  {'eventType': {'id': '3', 'name': 'Golf'}, 'marketCount': 66},
#  {'eventType': {'id': '4', 'name': 'Cricket'}, 'marketCount': 119},
#  {'eventType': {'id': '1477', 'name': 'Rugby League'}, 'marketCount': 49},
#  {'eventType': {'id': '5', 'name': 'Rugby Union'}, 'marketCount': 28},
#  {'eventType': {'id': '6', 'name': 'Boxing'}, 'marketCount': 54},
#  {'eventType': {'id': '7', 'name': 'Horse Racing'}, 'marketCount': 695},
#  {'eventType': {'id': '8', 'name': 'Motor Sport'}, 'marketCount': 16},
#  {'eventType': {'id': '27454571', 'name': 'Esports'}, 'marketCount': 84},
#  {'eventType': {'id': '10', 'name': 'Special Bets'}, 'marketCount': 4},
#  {'eventType': {'id': '998917', 'name': 'Volleyball'}, 'marketCount': 6},
#  {'eventType': {'id': '11', 'name': 'Cycling'}, 'marketCount': 3},
#  {'eventType': {'id': '2152880', 'name': 'Gaelic Games'}, 'marketCount': 32},
#  {'eventType': {'id': '6422', 'name': 'Snooker'}, 'marketCount': 1},
#  {'eventType': {'id': '7511', 'name': 'Baseball'}, 'marketCount': 41},
#  {'eventType': {'id': '6423', 'name': 'American Football'}, 'marketCount': 12},
#  {'eventType': {'id': '606611', 'name': 'Netball'}, 'marketCount': 4},
#  {'eventType': {'id': '7522', 'name': 'Basketball'}, 'marketCount': 52},
#  {'eventType': {'id': '61420', 'name': 'Australian Rules'},
#   'marketCount': 129},
#  {'eventType': {'id': '468328', 'name': 'Handball'}, 'marketCount': 6},
#  {'eventType': {'id': '3503', 'name': 'Darts'}, 'marketCount': 10},
#  {'eventType': {'id': '26420387', 'name': 'Mixed Martial Arts'},
#   'marketCount': 49},
#  {'eventType': {'id': '4339', 'name': 'Greyhound Racing'}, 'marketCount': 809},
#  {'eventType': {'id': '2378961', 'name': 'Politics'}, 'marketCount': 36}]

# %%
event_types = pd.DataFrame({'name':[], 'id':[], 'marketCount':[]})
for event in eventTypes['results']:

# %%
# example of reading specific event type
keys = eventTypes['result'][0]['eventType'].keys()

print(keys)
for key in keys:
    print(f"{key:5s}: {eventTypes['result'][4]['eventType'][key]}")
# Out:
# dict_keys(['id', 'name'])
# id   : 1477
# name : Rugby League

# %%
Inplay_req = '{"jsonrpc": "2.0", "method": "SportsAPING/v1.0/listMarketTypes", "params": {"filter":{"eventTypeIds":["1"]}}, "id": 1}'
# Inplay_req = '{"jsonrpc": "2.0", "method": "SportsAPING/v1.0/listMarketTypes", "params": {"filter":{"eventTypeIds":["7511"],\
#               "inPlayOnly":false}}, "id": 1}'
req = requests.post(bet_url, data=Inplay_req.encode('utf-8'), headers=headers) 
MarketTypes = req.json()
MarketTypes
# Out:
# {'jsonrpc': '2.0',
#  'result': [{'marketType': 'SPECIAL', 'marketCount': 2},
#   {'marketType': 'GROUP_WINNER', 'marketCount': 10},
#   {'marketType': 'SPECIALS_NEXT_MGR', 'marketCount': 2},
#   {'marketType': 'OVER_UNDER_25', 'marketCount': 365},
#   {'marketType': 'FIRST_HALF_GOALS_15', 'marketCount': 334},
#   {'marketType': 'FIRST_HALF_GOALS_05', 'marketCount': 331},
#   {'marketType': 'OVER_UNDER_75', 'marketCount': 334},
#   {'marketType': 'OVER_UNDER_45', 'marketCount': 339},
#   {'marketType': 'FIRST_HALF_GOALS_25', 'marketCount': 334},
#   {'marketType': 'OVER_UNDER_85', 'marketCount': 334},
#   {'marketType': 'BOTH_TEAMS_TO_SCORE', 'marketCount': 361},
#   {'marketType': 'ASIAN_HANDICAP', 'marketCount': 361},
#   {'marketType': 'CORRECT_SCORE', 'marketCount': 361},
#   {'marketType': 'MATCH_ODDS', 'marketCount': 398},
#   {'marketType': 'OVER_UNDER_05', 'marketCount': 349},
#   {'marketType': 'ALT_TOTAL_GOALS', 'marketCount': 361},
#   {'marketType': 'HALF_TIME_SCORE', 'marketCount': 339},
#   {'marketType': 'OVER_UNDER_15', 'marketCount': 339},
#   {'marketType': 'OVER_UNDER_35', 'marketCount': 339},
#   {'marketType': 'OVER_UNDER_55', 'marketCount': 339},
#   {'marketType': 'OVER_UNDER_65', 'marketCount': 339},
#   {'marketType': 'HALF_TIME_FULL_TIME', 'marketCount': 338},
#   {'marketType': 'TEAM_A_1', 'marketCount': 334},
#   {'marketType': 'DOUBLE_CHANCE', 'marketCount': 334},
#   {'marketType': 'HALF_TIME', 'marketCount': 340},
#   {'marketType': 'TEAM_B_1', 'marketCount': 334},
#   {'marketType': 'DRAW_NO_BET', 'marketCount': 334},
#   {'marketType': 'MATCH_ODDS_AND_BTTS', 'marketCount': 44},
#   {'marketType': 'ODD_OR_EVEN', 'marketCount': 44},
#   {'marketType': 'MATCH_ODDS_AND_OU_25', 'marketCount': 44},
#   {'marketType': 'TEAM_A_3', 'marketCount': 44},
#   {'marketType': 'TEAM_B_WIN_TO_NIL', 'marketCount': 44},
#   {'marketType': 'TEAM_B_3', 'marketCount': 44},
#   {'marketType': 'TEAM_A_WIN_TO_NIL', 'marketCount': 44},
#   {'marketType': 'TEAM_B_2', 'marketCount': 44},
#   {'marketType': 'TEAM_A_2', 'marketCount': 44},
#   {'marketType': 'CORNER_ODDS', 'marketCount': 7},
#   {'marketType': 'BOOKING_ODDS', 'marketCount': 7},
#   {'marketType': 'PLAYER_FOULS_2', 'marketCount': 3},
#   {'marketType': 'PLAYER_FOULS_1', 'marketCount': 3},
#   {'marketType': 'SENDING_OFF', 'marketCount': 7},
#   {'marketType': 'FIRST_GOAL_SCORER', 'marketCount': 7},
#   {'marketType': 'OVER_UNDER_85_CORNR', 'marketCount': 7},
#   {'marketType': 'OVER_UNDER_105_CORNR', 'marketCount': 7},
#   {'marketType': 'TEAM_A_OVER_UNDER_05', 'marketCount': 3},
#   {'marketType': 'SCORE_CAST', 'marketCount': 3},
#   {'marketType': 'SHOTS_ON_TARGET_P3', 'marketCount': 3},
#   {'marketType': 'SHOTS_ON_TARGET_P2', 'marketCount': 3},
#   {'marketType': 'TEAM_B_OVER_UNDER_25', 'marketCount': 3},
#   {'marketType': 'TEAM_A_OVER_UNDER_25', 'marketCount': 3},
#   {'marketType': 'TEAM_B_OVER_UNDER_15', 'marketCount': 3},
#   {'marketType': 'TEAM_B_OVER_UNDER_05', 'marketCount': 3},
#   {'marketType': 'TEAM_A_OVER_UNDER_15', 'marketCount': 3},
#   {'marketType': 'MATCH_SHOTS', 'marketCount': 4},
#   {'marketType': 'MATCH_ODDS_AND_OU_35', 'marketCount': 3},
#   {'marketType': 'CORRECT_SCORE2', 'marketCount': 6},
#   {'marketType': 'SHOTS_ON_TARGET_P1', 'marketCount': 3},
#   {'marketType': 'ANYTIME_ASSIST', 'marketCount': 3},
#   {'marketType': 'PENALTY_TAKEN', 'marketCount': 3},
#   {'marketType': 'SHOWN_A_CARD', 'marketCount': 7},
#   {'marketType': 'MATCH_SHOTS_TARGET', 'marketCount': 4},
#   {'marketType': 'TO_SCORE', 'marketCount': 7},
#   {'marketType': 'TO_SCORE_HATTRICK', 'marketCount': 7},
#   {'marketType': 'TO_SCORE_2_OR_MORE', 'marketCount': 7},
#   {'marketType': 'OVER_UNDER_35_CARDS', 'marketCount': 3},
#   {'marketType': 'OVER_UNDER_25_CARDS', 'marketCount': 3},
#   {'marketType': 'WINNER', 'marketCount': 6},
#   {'marketType': 'TO_REACH_SEMIS', 'marketCount': 1},
#   {'marketType': 'RELEGATION', 'marketCount': 1},
#   {'marketType': 'TOP_4_FINISH_FT', 'marketCount': 1},
#   {'marketType': 'TO_REACH_QUARTERS', 'marketCount': 1},
#   {'marketType': 'TO_REACH_FINAL', 'marketCount': 1}],
#  'id': 1}

# %%
MarketType = '["MATCH_ODDS"]'
MarketStartTime= datetime.datetime.now().strftime('%Y-%m-%dT%H:%M:%SZ')
MarketEndTime= (datetime.datetime.now() + datetime.timedelta(hours=24))
MarketEndTime = MarketEndTime.strftime('%Y-%m-%dT%H:%M:%SZ')

user_req='{"jsonrpc": "2.0", "method": "SportsAPING/v1.0/listMarketCatalogue",\
           "params": {"filter":{"eventTypeIds":["1"],"marketTypeCodes":'+MarketType+',\
           "marketStartTime":{"from":"'+MarketStartTime+'", "to":"'+MarketEndTime+'"}},"sort":"FIRST_TO_START",\
           "maxResults":"1", "marketProjection":["RUNNER_METADATA"]}, "id": 1}'

req = urllib.request.Request(bet_url, data=user_req.encode('utf-8'), headers=headers)
response= urllib.request.urlopen(req)
jsonResponse = response.read()
pkg = jsonResponse.decode('utf-8')
market_catalogue = json.loads(pkg) 
market_catalogue['result']
# Out:
# [{'marketId': '1.215143211',
#   'marketName': 'Match Odds',
#   'totalMatched': 245.94,
#   'runners': [{'selectionId': 5759566,
#     'runnerName': 'Tottori',
#     'handicap': 0.0,
#     'sortPriority': 1,
#     'metadata': {'runnerId': '5759566'}},
#    {'selectionId': 5026013,
#     'runnerName': 'Kitakyushu',
#     'handicap': 0.0,
#     'sortPriority': 2,
#     'metadata': {'runnerId': '5026013'}},
#    {'selectionId': 58805,
#     'runnerName': 'The Draw',
#     'handicap': 0.0,
#     'sortPriority': 3,
#     'metadata': {'runnerId': '58805'}}]}]

# %%
eventTypeID = '["7"]' #ID for Horse Racing
countryCode= '["GB","IE"]' #Country Codes. Betfair use Alpha-2 Codes under ISO 3166-1
marketTypeCode='["WIN"]' #Market Type
MarketStartTime= datetime.datetime.now().strftime('%Y-%m-%dT%H:%M:%SZ') #Event Start and End times
MarketEndTime = (datetime.datetime.now() + datetime.timedelta(hours=24))
MarketEndTime = MarketEndTime.strftime('%Y-%m-%dT%H:%M:%SZ')
maxResults = str(1000)
sortType = 'FIRST_TO_START' #Sorts the Output
Metadata = 'RUNNER_METADATA' #Provides metadata
inplay = 'false' #still to run

user_req='{"jsonrpc": "2.0", "method": "SportsAPING/v1.0/listMarketCatalogue",\
           "params": {"filter":{"eventTypeIds":'+eventTypeID+',"marketTypeCodes":'+marketTypeCode+',\
           "inPlayOnly":'+inplay+', "marketCountries":'+countryCode+',  \
           "marketStartTime":{"from":"'+MarketStartTime+'", "to":"'+MarketEndTime+'"}},\
           "sort":"'+sortType+'", "maxResults":"'+maxResults+'", "marketProjection":["'+Metadata+'"]}, "id": 1}'

req = urllib.request.Request(bet_url, data=user_req.encode('utf-8'), headers=headers)
response= urllib.request.urlopen(req)
jsonResponse = response.read()
pkg = jsonResponse.decode('utf-8')
result = json.loads(pkg) 
marketCatelogue = result['result']

# %%
marketCatelogue
# Out:
# [{'marketId': '1.215231863',
#   'marketName': '3m1f Nov Hcap Chs',
#   'totalMatched': 7516.44,
#   'runners': [{'selectionId': 36643074,
#     'runnerName': 'Shearer',
#     'handicap': 0.0,
#     'sortPriority': 1,
#     'metadata': {'SIRE_NAME': 'Flemensfirth',
#      'CLOTH_NUMBER_ALPHA': '1',
#      'OFFICIAL_RATING': None,
#      'COLOURS_DESCRIPTION': 'Royal blue, white hoops, maroon sleeves and cap',
#      'COLOURS_FILENAME': 'c20230616ain/00068612.jpg',
#      'FORECASTPRICE_DENOMINATOR': '4',
#      'DAMSIRE_NAME': 'Stowaway',
#      'WEIGHT_VALUE': '164',
#      'SEX_TYPE': 'G',
#      'DAYS_SINCE_LAST_RUN': '33',
#      'WEARING': 'Tongue strap,Cheek pieces',
#      'OWNER_NAME': 'McNeill Family',
#      'DAM_YEAR_BORN': '0',
#      'SIRE_BRED': 'USA',
#      'JOCKEY_NAME': 'H Cobden',
#      'DAM_BRED': 'IRL',
#      'ADJUSTED_RATING': None,
#      'runnerId': '36643074',
#      'CLOTH_NUMBER': '1',
#      'SIRE_YEAR_BORN': '1992',
#      'TRAINER_NAME': 'P F Nicholls',
#      'COLOUR_TYPE': 'b',
#      'AGE': '7',
#      'DAMSIRE_BRED': 'GBR',
#      'JOCKEY_CLAIM': '0',
#      'FORM': '11U88-1',
#      'FORECASTPRICE_NUMERATOR': '9',
#      'BRED': None,
#      'DAM_NAME': 'The Crown Jewel',
#      'DAMSIRE_YEAR_BORN': '1994',
#      'STALL_DRAW': None,
#      'WEIGHT_UNITS': 'pounds'}},
#    {'selectionId': 36600745,
#     'runnerName': 'Landen Calling',
#     'handicap': 0.0,
#     'sortPriority': 2,
#     'metadata': {'SIRE_NAME': 'Watar',
#      'CLOTH_NUMBER_ALPHA': '3',
#      'OFFICIAL_RATING': '125',
#      'COLOURS_DESCRIPTION': 'Black, white cross belts, halved sleeves, black and white quartered cap',
#      'COLOURS_FILENAME': 'c20230616ain/00073424.jpg',
#      'FORECASTPRICE_DENOMINATOR': '4',
#      'DAMSIRE_NAME': 'Silver Patriarch',
#      'WEIGHT_VALUE': '152',
#      'SEX_TYPE': 'G',
#      'DAYS_SINCE_LAST_RUN': '27',
#      'WEARING': 'Blinkers,Tongue strap',
#      'OWNER_NAME': 'The B Lucky Partnership',
#      'DAM_YEAR_BORN': '0',
#      'SIRE_BRED': 'IRL',
#      'JOCKEY_NAME': 'Jack Hogan',
#      'DAM_BRED': 'GBR',
#      'ADJUSTED_RATING': None,
#      'runnerId': '36600745',
#      'CLOTH_NUMBER': '3',
#      'SIRE_YEAR_BORN': '2005',
#      'TRAINER_NAME': "F O'Brien",
#      'COLOUR_TYPE': 'gr',
#      'AGE': '7',
#      'DAMSIRE_BRED': 'IRL',
#      'JOCKEY_CLAIM': '5',
#      'FORM': '23128-1',
#      'FORECASTPRICE_NUMERATOR': '11',
#      'BRED': None,
#      'DAM_NAME': 'Gill Hall Lady',
#      'DAMSIRE_YEAR_BORN': '1994',
#      'STALL_DRAW': None,
#      'WEIGHT_UNITS': 'pounds'}},
#    {'selectionId': 36655919,
#     'runnerName': 'Kakamora',
#     'handicap': 0.0,
#     'sortPriority': 3,
#     'metadata': {'SIRE_NAME': 'Great Pretender',
#      'CLOTH_NUMBER_ALPHA': '5',
#      'OFFICIAL_RATING': '120',
#      'COLOURS_DESCRIPTION': 'Red and white check, white cap',
#      'COLOURS_FILENAME': 'c20230616ain/00830790.jpg',
#      'FORECASTPRICE_DENOMINATOR': '1',
#      'DAMSIRE_NAME': 'Rocamadour',
#      'WEIGHT_VALUE': '147',
#      'SEX_TYPE': 'G',
#      'DAYS_SINCE_LAST_RUN': '13',
#      'WEARING': 'Cheek pieces,Tongue strap',
#      'OWNER_NAME': 'Tim Syder',
#      'DAM_YEAR_BORN': '0',
#      'SIRE_BRED': 'IRL',
#      'JOCKEY_NAME': 'Thomas Bellamy',
#      'DAM_BRED': 'GBR',
#      'ADJUSTED_RATING': None,
#      'runnerId': '36655919',
#      'CLOTH_NUMBER': '5',
#      'SIRE_YEAR_BORN': '1999',
#      'TRAINER_NAME': 'T R George',
#      'COLOUR_TYPE': 'b',
#      'AGE': '8',
#      'DAMSIRE_BRED': 'GBR',
#      'JOCKEY_CLAIM': '0',
#      'FORM': '6251-51',
#      'FORECASTPRICE_NUMERATOR': '3',
#      'BRED': None,
#      'DAM_NAME': 'Roche Dor',
#      'DAMSIRE_YEAR_BORN': '2002',
#      'STALL_DRAW': None,
#      'WEIGHT_UNITS': 'pounds'}},
#    {'selectionId': 38806845,
#     'runnerName': 'Jet Of Magic',
#     'handicap': 0.0,
#     'sortPriority': 4,
#     'metadata': {'SIRE_NAME': 'Jet Away',
#      'CLOTH_NUMBER_ALPHA': '2',
#      'OFFICIAL_RATING': '128',
#      'COLOURS_DESCRIPTION': 'Purple, red disc, striped sleeves and star on cap',
#      'COLOURS_FILENAME': 'c20230616ain/00878727.jpg',
#      'FORECASTPRICE_DENOMINATOR': '1',
#      'DAMSIRE_NAME': 'Definite Article',
#      'WEIGHT_VALUE': '155',
#      'SEX_TYPE': 'G',
#      'DAYS_SINCE_LAST_RUN': '64',
#      'WEARING': 'Cheek pieces',
#      'OWNER_NAME': 'Ts Equine',
#      'DAM_YEAR_BORN': '2000',
#      'SIRE_BRED': 'GBR',
#      'JOCKEY_NAME': 'Kielan Woods',
#      'DAM_BRED': 'IRL',
#      'ADJUSTED_RATING': None,
#      'runnerId': '38806845',
#      'CLOTH_NUMBER': '2',
#      'SIRE_YEAR_BORN': '2007',
#      'TRAINER_NAME': 'N A Twiston-Davies',
#      'COLOUR_TYPE': 'b',
#      'AGE': '7',
#      'DAMSIRE_BRED': 'ITA',
#      'JOCKEY_CLAIM': '0',
#      'FORM': '1223U4-',
#      'FORECASTPRICE_NUMERATOR': '6',
#      'BRED': None,
#      'DAM_NAME': 'Ginandit',
#      'DAMSIRE_YEAR_BORN': '0',
#      'STALL_DRAW': None,
#      'WEIGHT_UNITS': 'pounds'}},
#    {'selectionId': 38916747,
#     'runnerName': 'My Bobby Dazzler',
#     'handicap': 0.0,
#     'sortPriority': 5,
#     'metadata': {'SIRE_NAME': 'Malinas',
#      'CLOTH_NUMBER_ALPHA': '4',
#      'OFFICIAL_RATING': None,
#      'COLOURS_DESCRIPTION': 'Dark blue, white epaulets, white sleeves, dark blue armlets, white cap',
#      'COLOURS_FILENAME': 'c20230616ain/00829727.jpg',
#      'FORECASTPRICE_DENOMINATOR': '1',
#      'DAMSIRE_NAME': 'Kings Theatre',
#      'WEIGHT_VALUE': '147',
#      'SEX_TYPE': 'G',
#      'DAYS_SINCE_LAST_RUN': '1',
#      'WEARING': None,
#      'OWNER_NAME': 'Mr Bob Barrett',
#      'DAM_YEAR_BORN': '0',
#      'SIRE_BRED': 'DEU',
#      'JOCKEY_NAME': 'Alex Edwards',
#      'DAM_BRED': 'ZWE',
#      'ADJUSTED_RATING': None,
#      'runnerId': '38916747',
#      'CLOTH_NUMBER': '4',
#      'SIRE_YEAR_BORN': '2001',
#      'TRAINER_NAME': 'M Rowley',
#      'COLOUR_TYPE': 'b',
#      'AGE': '8',
#      'DAMSIRE_BRED': 'IRL',
#      'JOCKEY_CLAIM': '0',
#      'FORM': 'P524-31',
#      'FORECASTPRICE_NUMERATOR': '6',
#      'BRED': None,
#      'DAM_NAME': 'Ease And Grace',
#      'DAMSIRE_YEAR_BORN': '1991',
#      'STALL_DRAW': None,
#      'WEIGHT_UNITS': 'pounds'}}]},
#  {'marketId': '1.215236415',
#   'marketName': '1m4f Grp 3',
#   'totalMatched': 13512.1,
#   'runners': [{'selectionId': 6567661,
#     'runnerName': 'Rosscarbery',
#     'handicap': 0.0,
#     'sortPriority': 1,
#     'metadata': {'SIRE_NAME': 'Sea The Stars',
#      'CLOTH_NUMBER_ALPHA': '1',
#      'OFFICIAL_RATING': None,
#      'COLOURS_DESCRIPTION': 'Maroon',
#      'COLOURS_FILENAME': 'c20230616cor/00009130.jpg',
#      'FORECASTPRICE_DENOMINATOR': '2',
#      'DAMSIRE_NAME': 'Authorized',
#      'WEIGHT_VALUE': '138',
#      'SEX_TYPE': 'm',
#      'DAYS_SINCE_LAST_RUN': '244',
#      'WEARING': None,
#      'OWNER_NAME': 'Lady Bamford',
#      'DAM_YEAR_BORN': '2012',
#      'SIRE_BRED': 'IRE',
#      'JOCKEY_NAME': 'William James Lee',
#      'DAM_BRED': 'GER',
#      'ADJUSTED_RATING': None,
#      'runnerId': '6567661',
#      'CLOTH_NUMBER': '1',
#      'SIRE_YEAR_BORN': '2006',
#      'TRAINER_NAME': 'P. Twomey',
#      'COLOUR_TYPE': 'b',
#      'AGE': '5',
#      'DAMSIRE_BRED': 'IRE',
#      'JOCKEY_CLAIM': None,
#      'FORM': '191245-',
#      'FORECASTPRICE_NUMERATOR': '7',
#      'BRED': 'GER',
#      'DAM_NAME': 'Rose Rized',
#      'DAMSIRE_YEAR_BORN': '2004',
#      'STALL_DRAW': '3',
#      'WEIGHT_UNITS': 'pounds'}},
#    {'selectionId': 49696617,
#     'runnerName': 'Azazat',
#     'handicap': 0.0,
#     'sortPriority': 2,
#     'metadata': {'SIRE_NAME': 'Camelot',
#      'CLOTH_NUMBER_ALPHA': '5',
#      'OFFICIAL_RATING': None,
#      'COLOURS_DESCRIPTION': 'Green, red epaulettes, green cap',
#      'COLOURS_FILENAME': 'c20230616cor/00004318.jpg',
#      'FORECASTPRICE_DENOMINATOR': '2',
#      'DAMSIRE_NAME': 'Sea The Stars',
#      'WEIGHT_VALUE': '121',
#      'SEX_TYPE': 'f',
#      'DAYS_SINCE_LAST_RUN': '40',
#      'WEARING': None,
#      'OWNER_NAME': 'H. H. Aga Khan',
#      'DAM_YEAR_BORN': '2011',
#      'SIRE_BRED': 'UK',
#      'JOCKEY_NAME': 'C. D. Hayes',
#      'DAM_BRED': 'IRE',
#      'ADJUSTED_RATING': None,
#      'runnerId': '49696617',
#      'CLOTH_NUMBER': '5',
#      'SIRE_YEAR_BORN': '2009',
#      'TRAINER_NAME': 'D. K. Weld',
#      'COLOUR_TYPE': 'b',
#      'AGE': '3',
#      'DAMSIRE_BRED': 'IRE',
#      'JOCKEY_CLAIM': None,
#      'FORM': '2-31',
#      'FORECASTPRICE_NUMERATOR': '11',
#      'BRED': 'IRE',
#      'DAM_NAME': 'Azama',
#      'DAMSIRE_YEAR_BORN': '2006',
#      'STALL_DRAW': '1',
#      'WEIGHT_UNITS': 'pounds'}},
#    {'selectionId': 41554448,
#     'runnerName': 'Final Gesture',
#     'handicap': 0.0,
#     'sortPriority': 3,
#     'metadata': {'SIRE_NAME': 'Dubawi',
#      'CLOTH_NUMBER_ALPHA': '4',
#      'OFFICIAL_RATING': None,
#      'COLOURS_DESCRIPTION': 'Fluorescent orange and yellow blocks, diabolo on sleeves, yellow and orange hooped cap',
#      'COLOURS_FILENAME': 'c20230616cor/00061123.jpg',
#      'FORECASTPRICE_DENOMINATOR': '4',
#      'DAMSIRE_NAME': 'Galileo',
#      'WEIGHT_VALUE': '135',
#      'SEX_TYPE': 'f',
#      'DAYS_SINCE_LAST_RUN': '44',
#      'WEARING': None,
#      'OWNER_NAME': 'Bobby Flay',
#      'DAM_YEAR_BORN': '2010',
#      'SIRE_BRED': 'IRE',
#      'JOCKEY_NAME': 'R. P. Whelan',
#      'DAM_BRED': 'UK',
#      'ADJUSTED_RATING': None,
#      'runnerId': '41554448',
#      'CLOTH_NUMBER': '4',
#      'SIRE_YEAR_BORN': '2002',
#      'TRAINER_NAME': 'P. Twomey',
#      'COLOUR_TYPE': 'b',
#      'AGE': '4',
#      'DAMSIRE_BRED': 'IRE',
#      'JOCKEY_CLAIM': None,
#      'FORM': '21264-1',
#      'FORECASTPRICE_NUMERATOR': '11',
#      'BRED': 'IRE',
#      'DAM_NAME': 'Secret Gesture',
#      'DAMSIRE_YEAR_BORN': '1998',
#      'STALL_DRAW': '6',
#      'WEIGHT_UNITS': 'pounds'}},
#    {'selectionId': 20668895,
#     'runnerName': 'Lambada',
#     'handicap': 0.0,
#     'sortPriority': 4,
#     'metadata': {'SIRE_NAME': 'Dubawi',
#      'CLOTH_NUMBER_ALPHA': '6',
#      'OFFICIAL_RATING': None,
#      'COLOURS_DESCRIPTION': 'Purple, white seams, striped sleeves, purple cap',
#      'COLOURS_FILENAME': 'c20230616cor/00868476.jpg',
#      'FORECASTPRICE_DENOMINATOR': '1',
#      'DAMSIRE_NAME': 'Montjeu',
#      'WEIGHT_VALUE': '121',
#      'SEX_TYPE': 'f',
#      'DAYS_SINCE_LAST_RUN': '30',
#      'WEARING': None,
#      'OWNER_NAME': 'D.Smith,Mrs J.Magnier,M.Tabor,Westerberg',
#      'DAM_YEAR_BORN': '2009',
#      'SIRE_BRED': 'IRE',
#      'JOCKEY_NAME': 'Seamie Heffernan',
#      'DAM_BRED': 'IRE',
#      'ADJUSTED_RATING': None,
#      'runnerId': '20668895',
#      'CLOTH_NUMBER': '6',
#      'SIRE_YEAR_BORN': '2002',
#      'TRAINER_NAME': "Aidan O'Brien",
#      'COLOUR_TYPE': 'b',
#      'AGE': '3',
#      'DAMSIRE_BRED': 'IRE',
#      'JOCKEY_CLAIM': None,
#      'FORM': '03-16',
#      'FORECASTPRICE_NUMERATOR': '10',
#      'BRED': 'IRE',
#      'DAM_NAME': 'Wading',
#      'DAMSIRE_YEAR_BORN': '1996',
#      'STALL_DRAW': '7',
#      'WEIGHT_UNITS': 'pounds'}},
#    {'selectionId': 6476335,
#     'runnerName': 'Library',
#     'handicap': 0.0,
#     'sortPriority': 5,
#     'metadata': {'SIRE_NAME': 'Galileo',
#      'CLOTH_NUMBER_ALPHA': '7',
#      'OFFICIAL_RATING': None,
#      'COLOURS_DESCRIPTION': 'Royal blue, orange disc, striped sleeves and cap',
#      'COLOURS_FILENAME': 'c20230616cor/00868086.jpg',
#      'FORECASTPRICE_DENOMINATOR': '1',
#      'DAMSIRE_NAME': 'Dansili',
#      'WEIGHT_VALUE': '121',
#      'SEX_TYPE': 'f',
#      'DAYS_SINCE_LAST_RUN': '76',
#      'WEARING': 'blinkers',
#      'OWNER_NAME': 'M Tabor/D Smith/Mrs J Magnier/Westerberg',
#      'DAM_YEAR_BORN': '2012',
#      'SIRE_BRED': 'IRE',
#      'JOCKEY_NAME': 'W. M. Lordan',
#      'DAM_BRED': 'IRE',
#      'ADJUSTED_RATING': None,
#      'runnerId': '6476335',
#      'CLOTH_NUMBER': '7',
#      'SIRE_YEAR_BORN': '1998',
#      'TRAINER_NAME': "Aidan O'Brien",
#      'COLOUR_TYPE': 'b',
#      'AGE': '3',
#      'DAMSIRE_BRED': 'UK',
#      'JOCKEY_CLAIM': None,
#      'FORM': '32125-6',
#      'FORECASTPRICE_NUMERATOR': '20',
#      'BRED': 'IRE',
#      'DAM_NAME': 'Words',
#      'DAMSIRE_YEAR_BORN': '1996',
#      'STALL_DRAW': '2',
#      'WEIGHT_UNITS': 'pounds'}},
#    {'selectionId': 40178933,
#     'runnerName': 'Cairde Go Deo',
#     'handicap': 0.0,
#     'sortPriority': 6,
#     'metadata': {'SIRE_NAME': 'Camelot',
#      'CLOTH_NUMBER_ALPHA': '3',
#      'OFFICIAL_RATING': None,
#      'COLOURS_DESCRIPTION': 'Dark green, white spots on sleeves, dark green cap',
#      'COLOURS_FILENAME': 'c20230616cor/00852088.jpg',
#      'FORECASTPRICE_DENOMINATOR': '1',
#      'DAMSIRE_NAME': 'Elusive City',
#      'WEIGHT_VALUE': '135',
#      'SEX_TYPE': 'f',
#      'DAYS_SINCE_LAST_RUN': '28',
#      'WEARING': None,
#      'OWNER_NAME': 'Mr Mark Dobbin',
#      'DAM_YEAR_BORN': '2007',
#      'SIRE_BRED': 'UK',
#      'JOCKEY_NAME': 'C. T. Keane',
#      'DAM_BRED': 'IRE',
#      'ADJUSTED_RATING': None,
#      'runnerId': '40178933',
#      'CLOTH_NUMBER': '3',
#      'SIRE_YEAR_BORN': '2009',
#      'TRAINER_NAME': 'G. M. Lyons',
#      'COLOUR_TYPE': 'b',
#      'AGE': '4',
#      'DAMSIRE_BRED': 'USA',
#      'JOCKEY_CLAIM': None,
#      'FORM': '11325-7',
#      'FORECASTPRICE_NUMERATOR': '14',
#      'BRED': 'FR',
#      'DAM_NAME': 'Elusive Galaxy',
#      'DAMSIRE_YEAR_BORN': '2000',
#      'STALL_DRAW': '8',
#      'WEIGHT_UNITS': 'pounds'}},
#    {'selectionId': 55432325,
#     'runnerName': 'Thunder Roll',
#     'handicap': 0.0,
#     'sortPriority': 7,
#     'metadata': {'SIRE_NAME': 'Night of Thunder',
#      'CLOTH_NUMBER_ALPHA': '8',
#      'OFFICIAL_RATING': None,
#      'COLOURS_DESCRIPTION': 'Light blue, grey braces, grey diamonds on sleeves, light blue cap, grey diamonds',
#      'COLOURS_FILENAME': 'c20230616cor/00836810.jpg',
#      'FORECASTPRICE_DENOMINATOR': '1',
#      'DAMSIRE_NAME': 'Pivotal',
#      'WEIGHT_VALUE': '121',
#      'SEX_TYPE': 'f',
#      'DAYS_SINCE_LAST_RUN': '8',
#      'WEARING': None,
#      'OWNER_NAME': 'Annus Mirabilis Syndicate',
#      'DAM_YEAR_BORN': '2009',
#      'SIRE_BRED': 'IRE',
#      'JOCKEY_NAME': 'Declan McDonogh',
#      'DAM_BRED': 'UK',
#      'ADJUSTED_RATING': None,
#      'runnerId': '55432325',
#      'CLOTH_NUMBER': '8',
#      'SIRE_YEAR_BORN': '2011',
#      'TRAINER_NAME': "Joseph Patrick O'Brien",
#      'COLOUR_TYPE': 'ch',
#      'AGE': '3',
#      'DAMSIRE_BRED': 'UK',
#      'JOCKEY_CLAIM': None,
#      'FORM': '23',
#      'FORECASTPRICE_NUMERATOR': '11',
#      'BRED': 'IRE',
#      'DAM_NAME': 'Swingland',
#      'DAMSIRE_YEAR_BORN': '1993',
#      'STALL_DRAW': '4',
#      'WEIGHT_UNITS': 'pounds'}},
#    {'selectionId': 39135831,
#     'runnerName': 'Annerville',
#     'handicap': 0.0,
#     'sortPriority': 8,
#     'metadata': {'SIRE_NAME': 'Iffraaj',
#      'CLOTH_NUMBER_ALPHA': '2',
#      'OFFICIAL_RATING': None,
#      'COLOURS_DESCRIPTION': 'Beige, dark blue cross of lorraine and sleeves, dark blue cap, beige star',
#      'COLOURS_FILENAME': 'c20230616cor/00059259.jpg',
#      'FORECASTPRICE_DENOMINATOR': '1',
#      'DAMSIRE_NAME': 'Montjeu',
#      'WEIGHT_VALUE': '135',
#      'SEX_TYPE': 'm',
#      'DAYS_SINCE_LAST_RUN': '20',
#      'WEARING': 'blinkers',
#      'OWNER_NAME': 'Newtown Anner Stud Farm Ltd',
#      'DAM_YEAR_BORN': '2010',
#      'SIRE_BRED': 'UK',
#      'JOCKEY_NAME': 'Ben Martin Coen',
#      'DAM_BRED': 'IRE',
#      'ADJUSTED_RATING': None,
#      'runnerId': '39135831',
#      'CLOTH_NUMBER': '2',
#      'SIRE_YEAR_BORN': '2001',
#      'TRAINER_NAME': 'John Patrick Murtagh',
#      'COLOUR_TYPE': 'b',
#      'AGE': '5',
#      'DAMSIRE_BRED': 'IRE',
#      'JOCKEY_CLAIM': None,
#      'FORM': '650332',
#      'FORECASTPRICE_NUMERATOR': '8',
#      'BRED': 'IRE',
#      'DAM_NAME': 'Newellen',
#      'DAMSIRE_YEAR_BORN': '1996',
#      'STALL_DRAW': '5',
#      'WEIGHT_UNITS': 'pounds'}}]},
#  {'marketId': '1.215231825',
#   'marketName': '1m6f Hcap',
#   'totalMatched': 15413.36,
#   'runners': [{'selectionId': 28600363,
#     'runnerName': 'Ravens Ark',
#     'handicap': 0.0,
#     'sortPriority': 1,
#     'metadata': {'SIRE_NAME': 'Ravens Pass',
#      'CLOTH_NUMBER_ALPHA': '6',
#      'OFFICIAL_RATING': '80',
#      'COLOURS_DESCRIPTION': 'Light blue and grey diamonds, royal blue sleeves, royal blue cap, light blue diamonds',
#      'COLOURS_FILENAME': 'c20230616goo/00862395.jpg',
#      'FORECASTPRICE_DENOMINATOR': '3',
#      'DAMSIRE_NAME': 'Green Desert',
#      'WEIGHT_VALUE': '131',
#      'SEX_TYPE': 'G',
#      'DAYS_SINCE_LAST_RUN': '34',
#      'WEARING': None,
#      'OWNER_NAME': 'Beachview Corporation Ltd',
#      'DAM_YEAR_BORN': '2003',
#      'SIRE_BRED': 'USA',
#      'JOCKEY_NAME': 'James Doyle',
#      'DAM_BRED': 'GBR',
#      'ADJUSTED_RATING': None,
#      'runnerId': '28600363',
#      'CLOTH_NUMBER': '6',
#      'SIRE_YEAR_BORN': '2005',
#      'TRAINER_NAME': 'H Morrison',
#      'COLOUR_TYPE': 'ch',
#      'AGE': '6',
#      'DAMSIRE_BRED': 'USA',
#      'JOCKEY_CLAIM': '0',
#      'FORM': '03349-2',
#      'FORECASTPRICE_NUMERATOR': '10',
#      'BRED': None,
#      'DAM_NAME': 'Wonderful Desert',
#      'DAMSIRE_YEAR_BORN': '1983',
#      'STALL_DRAW': '7',
#      'WEIGHT_UNITS': 'pounds'}},
#    {'selectionId': 35528119,
#     'runnerName': 'Crescent Lake',
#     'handicap': 0.0,
#     'sortPriority': 2,
#     'metadata': {'SIRE_NAME': 'Oasis Dream',
#      'CLOTH_NUMBER_ALPHA': '8',
#      'OFFICIAL_RATING': '80',
#      'COLOURS_DESCRIPTION': 'Dark green and purple diabolo, purple sleeves, quartered cap',
#      'COLOURS_FILENAME': 'c20230616goo/00874869.jpg',
#      'FORECASTPRICE_DENOMINATOR': '2',
#      'DAMSIRE_NAME': 'Boundary',
#      'WEIGHT_VALUE': '131',
#      'SEX_TYPE': 'G',
#      'DAYS_SINCE_LAST_RUN': '257',
#      'WEARING': None,
#      'OWNER_NAME': 'Palace Racing',
#      'DAM_YEAR_BORN': '1998',
#      'SIRE_BRED': 'GBR',
#      'JOCKEY_NAME': 'T P Queally',
#      'DAM_BRED': 'USA',
#      'ADJUSTED_RATING': None,
#      'runnerId': '35528119',
#      'CLOTH_NUMBER': '8',
#      'SIRE_YEAR_BORN': '2000',
#      'TRAINER_NAME': 'G L Moore',
#      'COLOUR_TYPE': 'b',
#      'AGE': '6',
#      'DAMSIRE_BRED': 'USA',
#      'JOCKEY_CLAIM': '0',
#      'FORM': '831414',
#      'FORECASTPRICE_NUMERATOR': '11',
#      'BRED': None,
#      'DAM_NAME': 'Santolina',
#      'DAMSIRE_YEAR_BORN': '1990',
#      'STALL_DRAW': '2',
#      'WEIGHT_UNITS': 'pounds'}},
#    {'selectionId': 39532798,
#     'runnerName': 'Vaynor',
#     'handicap': 0.0,
#     'sortPriority': 3,
#     'metadata': {'SIRE_NAME': 'Mastercraftsman',
#      'CLOTH_NUMBER_ALPHA': '3',
#      'OFFICIAL_RATING': '83',
#      'COLOURS_DESCRIPTION': 'Pink, emerald green chevron, halved sleeves, emerald green and pink quartered cap',
#      'COLOURS_FILENAME': 'c20230616goo/00032921.jpg',
#      'FORECASTPRICE_DENOMINATOR': '2',
#      'DAMSIRE_NAME': 'Barathea',
#      'WEIGHT_VALUE': '134',
#      'SEX_TYPE': 'G',
#      'DAYS_SINCE_LAST_RUN': '41',
#      'WEARING': None,
#      'OWNER_NAME': 'Mrs Fitri Hay',
#      'DAM_YEAR_BORN': '2003',
#      'SIRE_BRED': 'IRL',
#      'JOCKEY_NAME': 'Kevin Stott',
#      'DAM_BRED': 'IRL',
#      'ADJUSTED_RATING': None,
#      'runnerId': '39532798',
#      'CLOTH_NUMBER': '3',
#      'SIRE_YEAR_BORN': '2006',
#      'TRAINER_NAME': 'C Hills',
#      'COLOUR_TYPE': 'ro',
#      'AGE': '4',
#      'DAMSIRE_BRED': 'IRL',
#      'JOCKEY_CLAIM': '0',
#      'FORM': '54211-0',
#      'FORECASTPRICE_NUMERATOR': '13',
#      'BRED': None,
#      'DAM_NAME': 'Sanaya',
#      'DAMSIRE_YEAR_BORN': '1990',
#      'STALL_DRAW': '9',
#      'WEIGHT_UNITS': 'pounds'}},
#    {'selectionId': 8338762,
#     'runnerName': 'Wilderness',
#     'handicap': 0.0,
#     'sortPriority': 4,
#     'metadata': {'SIRE_NAME': 'Cityscape',
#      'CLOTH_NUMBER_ALPHA': '10',
#      'OFFICIAL_RATING': '78',
#      'COLOURS_DESCRIPTION': 'Yellow, emerald green and yellow striped sleeves',
#      'COLOURS_FILENAME': 'c20230616goo/00833321A.jpg',
#      'FORECASTPRICE_DENOMINATOR': '1',
#      'DAMSIRE_NAME': 'Royal Applause',
#      'WEIGHT_VALUE': '129',
#      'SEX_TYPE': 'M',
#      'DAYS_SINCE_LAST_RUN': '378',
#      'WEARING': 'Blinkers',
#      'OWNER_NAME': 'S Mullins Racing Club',
#      'DAM_YEAR_BORN': '2004',
#      'SIRE_BRED': 'GBR',
#      'JOCKEY_NAME': 'George Downing',
#      'DAM_BRED': 'GBR',
#      'ADJUSTED_RATING': None,
#      'runnerId': '8338762',
#      'CLOTH_NUMBER': '10',
#      'SIRE_YEAR_BORN': '2006',
#      'TRAINER_NAME': 'J W Mullins',
#      'COLOUR_TYPE': 'b',
#      'AGE': '8',
#      'DAMSIRE_BRED': 'GBR',
#      'JOCKEY_CLAIM': '0',
#      'FORM': '295-492',
#      'FORECASTPRICE_NUMERATOR': '10',
#      'BRED': None,
#      'DAM_NAME': 'Moonlight Applause',
#      'DAMSIRE_YEAR_BORN': '1993',
#      'STALL_DRAW': '1',
#      'WEIGHT_UNITS': 'pounds'}},
#    {'selectionId': 18091330,
#     'runnerName': 'Get Back Get Back',
#     'handicap': 0.0,
#     'sortPriority': 5,
#     'metadata': {'SIRE_NAME': 'Lord Shanakill',
#      'CLOTH_NUMBER_ALPHA': '7',
#      'OFFICIAL_RATING': None,
#      'COLOURS_DESCRIPTION': 'White and dark blue (quartered), checked sleeves',
#      'COLOURS_FILENAME': 'c20230616goo/00878391.jpg',
#      'FORECASTPRICE_DENOMINATOR': '1',
#      'DAMSIRE_NAME': 'Kingmambo',
#      'WEIGHT_VALUE': '131',
#      'SEX_TYPE': 'G',
#      'DAYS_SINCE_LAST_RUN': '1102',
#      'WEARING': 'Tongue strap',
#      'OWNER_NAME': 'D Charlesworth & D Turner',
#      'DAM_YEAR_BORN': '0',
#      'SIRE_BRED': 'USA',
#      'JOCKEY_NAME': 'Saffie Osborne',
#      'DAM_BRED': 'USA',
#      'ADJUSTED_RATING': None,
#      'runnerId': '18091330',
#      'CLOTH_NUMBER': '7',
#      'SIRE_YEAR_BORN': '2006',
#      'TRAINER_NAME': 'H Fry',
#      'COLOUR_TYPE': 'b',
#      'AGE': '8',
#      'DAMSIRE_BRED': 'USA',
#      'JOCKEY_CLAIM': '0',
#      'FORM': '148637/',
#      'FORECASTPRICE_NUMERATOR': '12',
#      'BRED': None,
#      'DAM_NAME': 'Bawaakeer',
#      'DAMSIRE_YEAR_BORN': '1990',
#      'STALL_DRAW': '8',
#      'WEIGHT_UNITS': 'pounds'}},
#    {'selectionId': 41122648,
#     'runnerName': 'Juan Bermudez',
#     'handicap': 0.0,
#     'sortPriority': 6,
#     'metadata': {'SIRE_NAME': 'Nathaniel',
#      'CLOTH_NUMBER_ALPHA': '1',
#      'OFFICIAL_RATING': '84',
#      'COLOURS_DESCRIPTION': 'DARK BLUE, PINK striped sleeves',
#      'COLOURS_FILENAME': 'c20230616goo/00869829A.jpg',
#      'FORECASTPRICE_DENOMINATOR': '1',
#      'DAMSIRE_NAME': 'Whywhywhy',
#      'WEIGHT_VALUE': '135',
#      'SEX_TYPE': 'G',
#      'DAYS_SINCE_LAST_RUN': '35',
#      'WEARING': 'Cheek pieces,Tongue strap',
#      'OWNER_NAME': 'The Bermuda Salman Morris Partnership',
#      'DAM_YEAR_BORN': '2009',
#      'SIRE_BRED': 'IRL',
#      'JOCKEY_NAME': 'David Probert',
#      'DAM_BRED': 'USA',
#      'ADJUSTED_RATING': None,
#      'runnerId': '41122648',
#      'CLOTH_NUMBER': '1',
#      'SIRE_YEAR_BORN': '2008',
#      'TRAINER_NAME': 'A M Balding',
#      'COLOUR_TYPE': 'ch',
#      'AGE': '4',
#      'DAMSIRE_BRED': 'USA',
#      'JOCKEY_CLAIM': '0',
#      'FORM': '4319-40',
#      'FORECASTPRICE_NUMERATOR': '7',
#      'BRED': None,
#      'DAM_NAME': 'Long Face',
#      'DAMSIRE_YEAR_BORN': '2000',
#      'STALL_DRAW': '3',
#      'WEIGHT_UNITS': 'pounds'}},
#    {'selectionId': 394585,
#     'runnerName': 'Military Two Step',
#     'handicap': 0.0,
#     'sortPriority': 7,
#     'metadata': {'SIRE_NAME': 'Jukebox Jury',
#      'CLOTH_NUMBER_ALPHA': '5',
#      'OFFICIAL_RATING': None,
#      'COLOURS_DESCRIPTION': 'Dark blue, large white spots, dark blue and white chevrons on sleeves, dark blue and white striped cap',
#      'COLOURS_FILENAME': 'c20230616goo/00868528.jpg',
#      'FORECASTPRICE_DENOMINATOR': '2',
#      'DAMSIRE_NAME': 'Giants Causeway',
#      'WEIGHT_VALUE': '134',
#      'SEX_TYPE': 'M',
#      'DAYS_SINCE_LAST_RUN': '35',
#      'WEARING': 'Blinkers',
#      'OWNER_NAME': 'C R Hirst & Dougie Livingston',
#      'DAM_YEAR_BORN': '2005',
#      'SIRE_BRED': 'IRL',
#      'JOCKEY_NAME': 'J Fanning',
#      'DAM_BRED': 'USA',
#      'ADJUSTED_RATING': None,
#      'runnerId': '394585',
#      'CLOTH_NUMBER': '5',
#      'SIRE_YEAR_BORN': '2006',
#      'TRAINER_NAME': 'Charlie Johnston',
#      'COLOUR_TYPE': 'gr',
#      'AGE': '5',
#      'DAMSIRE_BRED': 'USA',
#      'JOCKEY_CLAIM': '0',
#      'FORM': '1-43658',
#      'FORECASTPRICE_NUMERATOR': '9',
#      'BRED': None,
#      'DAM_NAME': 'Step This Way',
#      'DAMSIRE_YEAR_BORN': '1997',
#      'STALL_DRAW': '4',
#      'WEIGHT_UNITS': 'pounds'}},
#    {'selectionId': 27997524,
#     'runnerName': 'Songo',
#     'handicap': 0.0,
#     'sortPriority': 8,
#     'metadata': {'SIRE_NAME': 'Most Improved',
#      'CLOTH_NUMBER_ALPHA': '9',
#      'OFFICIAL_RATING': '78',
#      'COLOURS_DESCRIPTION': 'Emerald green, orange hoops, emerald green cap',
#      'COLOURS_FILENAME': 'c20230616goo/00874041.jpg',
#      'FORECASTPRICE_DENOMINATOR': '1',
#      'DAMSIRE_NAME': 'Acclamation',
#      'WEIGHT_VALUE': '129',
#      'SEX_TYPE': 'G',
#      'DAYS_SINCE_LAST_RUN': '786',
#      'WEARING': 'Hood',
#      'OWNER_NAME': 'The Songo Partnership',
#      'DAM_YEAR_BORN': '2008',
#      'SIRE_BRED': 'IRL',
#      'JOCKEY_NAME': 'Jim Crowley',
#      'DAM_BRED': 'IRL',
#      'ADJUSTED_RATING': None,
#      'runnerId': '27997524',
#      'CLOTH_NUMBER': '9',
#      'SIRE_YEAR_BORN': '2009',
#      'TRAINER_NAME': 'M F Harris',
#      'COLOUR_TYPE': 'b',
#      'AGE': '7',
#      'DAMSIRE_BRED': 'GBR',
#      'JOCKEY_CLAIM': '0',
#      'FORM': '21996-9',
#      'FORECASTPRICE_NUMERATOR': '25',
#      'BRED': None,
#      'DAM_NAME': 'Sacre Fleur',
#      'DAMSIRE_YEAR_BORN': '1999',
#      'STALL_DRAW': '10',
#      'WEIGHT_UNITS': 'pounds'}},
#    {'selectionId': 32879540,
#     'runnerName': 'State Of Bliss',
#     'handicap': 0.0,
#     'sortPriority': 9,
#     'metadata': {'SIRE_NAME': 'Gleneagles',
#      'CLOTH_NUMBER_ALPHA': '4',
#      'OFFICIAL_RATING': '83',
#      'COLOURS_DESCRIPTION': 'Dark blue, yellow cross of lorraine, red sleeves, dark blue cap, yellow star',
#      'COLOURS_FILENAME': 'c20230616goo/00832254.jpg',
#      'FORECASTPRICE_DENOMINATOR': '1',
#      'DAMSIRE_NAME': 'Danehill',
#      'WEIGHT_VALUE': '134',
#      'SEX_TYPE': 'G',
#      'DAYS_SINCE_LAST_RUN': '255',
#      'WEARING': None,
#      'OWNER_NAME': 'The Ridgeway Racing For Fun Partnershi',
#      'DAM_YEAR_BORN': '1999',
#      'SIRE_BRED': 'IRL',
#      'JOCKEY_NAME': 'Charles Bishop',
#      'DAM_BRED': 'IRL',
#      'ADJUSTED_RATING': None,
#      'runnerId': '32879540',
#      'CLOTH_NUMBER': '4',
#      'SIRE_YEAR_BORN': '2004',
#      'TRAINER_NAME': 'N B King',
#      'COLOUR_TYPE': 'b',
#      'AGE': '5',
#      'DAMSIRE_BRED': 'USA',
#      'JOCKEY_CLAIM': '0',
#      'FORM': '508037-',
#      'FORECASTPRICE_NUMERATOR': '8',
#      'BRED': None,
#      'DAM_NAME': 'Crystal Valkyrie',
#      'DAMSIRE_YEAR_BORN': '1986',
#      'STALL_DRAW': '11',
#      'WEIGHT_UNITS': 'pounds'}},
#    {'selectionId': 40043803,
#     'runnerName': 'Buxted Reel',
#     'handicap': 0.0,
#     'sortPriority': 10,
#     'metadata': {'SIRE_NAME': 'Highland Reel',
#      'CLOTH_NUMBER_ALPHA': '11',
#      'OFFICIAL_RATING': None,
#      'COLOURS_DESCRIPTION': 'Royal blue, white hoops, yellow and white halved sleeves, yellow cap',
#      'COLOURS_FILENAME': 'c20230616goo/00028242.jpg',
#      'FORECASTPRICE_DENOMINATOR': '1',
#      'DAMSIRE_NAME': 'Machiavellian',
#      'WEIGHT_VALUE': '119',
#      'SEX_TYPE': 'G',
#      'DAYS_SINCE_LAST_RUN': '33',
#      'WEARING': 'Hood',
#      'OWNER_NAME': 'Buxted Partnership',
#      'DAM_YEAR_BORN': '0',
#      'SIRE_BRED': 'IRL',
#      'JOCKEY_NAME': 'J P Fahy',
#      'DAM_BRED': 'GBR',
#      'ADJUSTED_RATING': None,
#      'runnerId': '40043803',
#      'CLOTH_NUMBER': '11',
#      'SIRE_YEAR_BORN': '2012',
#      'TRAINER_NAME': 'Ian Williams',
#      'COLOUR_TYPE': 'b',
#      'AGE': '4',
#      'DAMSIRE_BRED': 'USA',
#      'JOCKEY_CLAIM': '0',
#      'FORM': '1624-60',
#      'FORECASTPRICE_NUMERATOR': '20',
#      'BRED': None,
#      'DAM_NAME': 'Blue Lightning',
#      'DAMSIRE_YEAR_BORN': '1987',
#      'STALL_DRAW': '5',
#      'WEIGHT_UNITS': 'pounds'}},
#    {'selectionId': 20303783,
#     'runnerName': 'Aced It',
#     'handicap': 0.0,
#     'sortPriority': 11,
#     'metadata': {'SIRE_NAME': 'Lope De Vega',
#      'CLOTH_NUMBER_ALPHA': '2',
#      'OFFICIAL_RATING': '84',
#      'COLOURS_DESCRIPTION': 'Dark green and beige stripes',
#      'COLOURS_FILENAME': 'c20230616goo/00833850.jpg',
#      'FORECASTPRICE_DENOMINATOR': '1',
#      'DAMSIRE_NAME': 'Galileo',
#      'WEIGHT_VALUE': '135',
#      'SEX_TYPE': 'G',
#      'DAYS_SINCE_LAST_RUN': '28',
#      'WEARING': 'Tongue strap',
#      'OWNER_NAME': 'Crowd Racing Partnership',
#      'DAM_YEAR_BORN': '2006',
#      'SIRE_BRED': 'IRL',
#      'JOCKEY_NAME': 'Ray Dawson',
#      'DAM_BRED': 'GBR',
#      'ADJUSTED_RATING': None,
#      'runnerId': '20303783',
#      'CLOTH_NUMBER': '2',
#      'SIRE_YEAR_BORN': '2007',
#      'TRAINER_NAME': 'C Poulton',
#      'COLOUR_TYPE': 'b',
#      'AGE': '7',
#      'DAMSIRE_BRED': 'IRL',
#      'JOCKEY_CLAIM': '0',
#      'FORM': '143498',
#      'FORECASTPRICE_NUMERATOR': '20',
#      'BRED': None,
#      'DAM_NAME': 'Farranjordan',
#      'DAMSIRE_YEAR_BORN': '1998',
#      'STALL_DRAW': '6',
#      'WEIGHT_UNITS': 'pounds'}}]},
#  {'marketId': '1.215231781',
#   'marketName': '2m6f Hcap Hrd',
#   'totalMatched': 9246.1,
#   'runners': [{'selectionId': 5123294,
#     'runnerName': 'Another Mystery',
#     'handicap': 0.0,
#     'sortPriority': 1,
#     'metadata': {'SIRE_NAME': 'Norse Dancer',
#      'CLOTH_NUMBER_ALPHA': '2',
#      'OFFICIAL_RATING': None,
#      'COLOURS_DESCRIPTION': 'Emerald green and red (quartered), emerald green sleeves, red armlets',
#      'COLOURS_FILENAME': 'c20230616fon/00870732.jpg',
#      'FORECASTPRICE_DENOMINATOR': '2',
#      'DAMSIRE_NAME': 'Relief Pitcher',
#      'WEIGHT_VALUE': '161',
#      'SEX_TYPE': 'G',
#      'DAYS_SINCE_LAST_RUN': '25',
#      'WEARING': 'Cheek pieces',
#      'OWNER_NAME': 'J And J McAndrew',
#      'DAM_YEAR_BORN': '0',
#      'SIRE_BRED': 'IRL',
#      'JOCKEY_NAME': 'N de Boinville',
#      'DAM_BRED': 'ZWE',
#      'ADJUSTED_RATING': None,
#      'runnerId': '5123294',
#      'CLOTH_NUMBER': '2',
#      'SIRE_YEAR_BORN': '2000',
#      'TRAINER_NAME': 'L Wadham',
#      'COLOUR_TYPE': 'b',
#      'AGE': '6',
#      'DAMSIRE_BRED': 'ZWE',
#      'JOCKEY_CLAIM': '0',
#      'FORM': '4PP75-1',
#      'FORECASTPRICE_NUMERATOR': '5',
#      'BRED': None,
#      'DAM_NAME': 'Misstree Pitcher',
#      'DAMSIRE_YEAR_BORN': '0',
#      'STALL_DRAW': None,
#      'WEIGHT_UNITS': 'pounds'}},
#    {'selectionId': 46529943,
#     'runnerName': 'Coconut Twist',
#     'handicap': 0.0,
#     'sortPriority': 2,
#     'metadata': {'SIRE_NAME': 'Shantou',
#      'CLOTH_NUMBER_ALPHA': '5',
#      'OFFICIAL_RATING': None,
#      'COLOURS_DESCRIPTION': 'Grey, pink seams, grey cap',
#      'COLOURS_FILENAME': 'c20230616fon/00866187.jpg',
#      'FORECASTPRICE_DENOMINATOR': '1',
#      'DAMSIRE_NAME': 'Presenting',
#      'WEIGHT_VALUE': '149',
#      'SEX_TYPE': 'G',
#      'DAYS_SINCE_LAST_RUN': '23',
#      'WEARING': None,
#      'OWNER_NAME': 'Troika Racing',
#      'DAM_YEAR_BORN': '0',
#      'SIRE_BRED': 'USA',
#      'JOCKEY_NAME': 'Harry Reed',
#      'DAM_BRED': 'IRL',
#      'ADJUSTED_RATING': None,
#      'runnerId': '46529943',
#      'CLOTH_NUMBER': '5',
#      'SIRE_YEAR_BORN': '1993',
#      'TRAINER_NAME': 'B Barr',
#      'COLOUR_TYPE': 'ch',
#      'AGE': '5',
#      'DAMSIRE_BRED': 'GBR',
#      'JOCKEY_CLAIM': '0',
#      'FORM': 'P640-22',
#      'FORECASTPRICE_NUMERATOR': '3',
#      'BRED': None,
#      'DAM_NAME': 'Presenting Chaos',
#      'DAMSIRE_YEAR_BORN': '1992',
#      'STALL_DRAW': None,
#      'WEIGHT_UNITS': 'pounds'}},
#    {'selectionId': 20556996,
#     'runnerName': 'Whenitrainsitpours',
#     'handicap': 0.0,
#     'sortPriority': 3,
#     'metadata': {'SIRE_NAME': 'Leading Light',
#      'CLOTH_NUMBER_ALPHA': '3',
#      'OFFICIAL_RATING': '88',
#      'COLOURS_DESCRIPTION': 'Emerald green, orange seams, white sleeves, orange armlets, orange cap',
#      'COLOURS_FILENAME': 'c20230616fon/00876079.jpg',
#      'FORECASTPRICE_DENOMINATOR': '1',
#      'DAMSIRE_NAME': 'Gulch',
#      'WEIGHT_VALUE': '156',
#      'SEX_TYPE': 'G',
#      'DAYS_SINCE_LAST_RUN': '18',
#      'WEARING': None,
#      'OWNER_NAME': 'The Rebels',
#      'DAM_YEAR_BORN': '2003',
#      'SIRE_BRED': 'IRL',
#      'JOCKEY_NAME': 'Bradley Harris',
#      'DAM_BRED': 'GBR',
#      'ADJUSTED_RATING': None,
#      'runnerId': '20556996',
#      'CLOTH_NUMBER': '3',
#      'SIRE_YEAR_BORN': '1996',
#      'TRAINER_NAME': 'M F Harris',
#      'COLOUR_TYPE': 'ch',
#      'AGE': '5',
#      'DAMSIRE_BRED': 'USA',
#      'JOCKEY_CLAIM': '5',
#      'FORM': '8437-44',
#      'FORECASTPRICE_NUMERATOR': '8',
#      'BRED': None,
#      'DAM_NAME': 'Zaharath Al Bustan',
#      'DAMSIRE_YEAR_BORN': '1984',
#      'STALL_DRAW': None,
#      'WEIGHT_UNITS': 'pounds'}},
#    {'selectionId': 36476458,
#     'runnerName': 'Dynamic Kate',
#     'handicap': 0.0,
#     'sortPriority': 4,
#     'metadata': {'SIRE_NAME': 'Yeats',
#      'CLOTH_NUMBER_ALPHA': '1',
#      'OFFICIAL_RATING': '100',
#      'COLOURS_DESCRIPTION': 'White, dark blue seams, dark blue sleeves, grey seams, dark blue cap, orange diamond',
#      'COLOURS_FILENAME': 'c20230616fon/00069537.jpg',
#      'FORECASTPRICE_DENOMINATOR': '1',
#      'DAMSIRE_NAME': 'Alflora',
#      'WEIGHT_VALUE': '168',
#      'SEX_TYPE': 'M',
#      'DAYS_SINCE_LAST_RUN': '33',
#      'WEARING': 'Cheek pieces,Tongue strap',
#      'OWNER_NAME': 'BG Racing Partnership',
#      'DAM_YEAR_BORN': '2003',
#      'SIRE_BRED': 'IRL',
#      'JOCKEY_NAME': 'Joe Anderson',
#      'DAM_BRED': 'GBR',
#      'ADJUSTED_RATING': None,
#      'runnerId': '36476458',
#      'CLOTH_NUMBER': '1',
#      'SIRE_YEAR_BORN': '2001',
#      'TRAINER_NAME': 'N P Mulholland',
#      'COLOUR_TYPE': 'br',
#      'AGE': '7',
#      'DAMSIRE_BRED': 'IRL',
#      'JOCKEY_CLAIM': '5',
#      'FORM': 'U121F-3',
#      'FORECASTPRICE_NUMERATOR': '5',
#      'BRED': None,
#      'DAM_NAME': 'Alverstone',
#      'DAMSIRE_YEAR_BORN': '1989',
#      'STALL_DRAW': None,
#      'WEIGHT_UNITS': 'pounds'}},
#    {'selectionId': 14528155,
#     'runnerName': 'Happy Returns',
#     'handicap': 0.0,
#     'sortPriority': 5,
#     'metadata': {'SIRE_NAME': 'Recharge',
#      'CLOTH_NUMBER_ALPHA': '8',
#      'OFFICIAL_RATING': '78',
#      'COLOURS_DESCRIPTION': 'Dark blue, grey star and star on cap',
#      'COLOURS_FILENAME': 'c20230616fon/00048087.jpg',
#      'FORECASTPRICE_DENOMINATOR': '1',
#      'DAMSIRE_NAME': 'Alflora',
#      'WEIGHT_VALUE': '146',
#      'SEX_TYPE': 'M',
#      'DAYS_SINCE_LAST_RUN': '29',
#      'WEARING': None,
#      'OWNER_NAME': 'Wincanton Race Club',
#      'DAM_YEAR_BORN': '0',
#      'SIRE_BRED': 'IRL',
#      'JOCKEY_NAME': 'James Best',
#      'DAM_BRED': 'GBR',
#      'ADJUSTED_RATING': None,
#      'runnerId': '14528155',
#      'CLOTH_NUMBER': '8',
#      'SIRE_YEAR_BORN': '2006',
#      'TRAINER_NAME': 'N P Mulholland',
#      'COLOUR_TYPE': 'b',
#      'AGE': '6',
#      'DAMSIRE_BRED': 'IRL',
#      'JOCKEY_CLAIM': '0',
#      'FORM': '679F4-4',
#      'FORECASTPRICE_NUMERATOR': '4',
#      'BRED': None,
#      'DAM_NAME': 'Bonne Anniversaire',
#      'DAMSIRE_YEAR_BORN': '1989',
#      'STALL_DRAW': None,
#      'WEIGHT_UNITS': 'pounds'}},
#    {'selectionId': 1543039,
#     'runnerName': 'Queens Fortune',
#     'handicap': 0.0,
#     'sortPriority': 6,
#     'metadata': {'SIRE_NAME': 'Soldier Of Fortune',
#      'CLOTH_NUMBER_ALPHA': '4',
#      'OFFICIAL_RATING': None,
#      'COLOURS_DESCRIPTION': 'Red, white chevron, royal blue sleeves, yellow stars, white cap',
#      'COLOURS_FILENAME': 'c20230616fon/00875875.jpg',
#      'FORECASTPRICE_DENOMINATOR': '1',
#      'DAMSIRE_NAME': 'Fourstars Allstar',
#      'WEIGHT_VALUE': '150',
#      'SEX_TYPE': 'M',
#      'DAYS_SINCE_LAST_RUN': '72',
#      'WEARING': 'Tongue strap',
#      'OWNER_NAME': 'Noel Fehily Racing Syndicates Queens F',
#      'DAM_YEAR_BORN': '2002',
#      'SIRE_BRED': 'IRL',
#      'JOCKEY_NAME': 'Sam Twiston-Davies',
#      'DAM_BRED': 'IRL',
#      'ADJUSTED_RATING': None,
#      'runnerId': '1543039',
#      'CLOTH_NUMBER': '4',
#      'SIRE_YEAR_BORN': '2004',
#      'TRAINER_NAME': 'A J Honeyball',
#      'COLOUR_TYPE': 'b',
#      'AGE': '5',
#      'DAMSIRE_BRED': 'USA',
#      'JOCKEY_CLAIM': '0',
#      'FORM': '3/94PP7-',
#      'FORECASTPRICE_NUMERATOR': '12',
#      'BRED': None,
#      'DAM_NAME': 'Down By The Sea',
#      'DAMSIRE_YEAR_BORN': '1988',
#      'STALL_DRAW': None,
#      'WEIGHT_UNITS': 'pounds'}},
#    {'selectionId': 41192922,
#     'runnerName': 'Zyras Lioness',
#     'handicap': 0.0,
#     'sortPriority': 7,
#     'metadata': {'SIRE_NAME': 'Sixties Icon',
#      'CLOTH_NUMBER_ALPHA': '7',
#      'OFFICIAL_RATING': '80',
#      'COLOURS_DESCRIPTION': 'Black, beige stars, black sleeves, beige cap, black star',
#      'COLOURS_FILENAME': 'c20230616fon/00839767.jpg',
#      'FORECASTPRICE_DENOMINATOR': '1',
#      'DAMSIRE_NAME': 'Piccolo',
#      'WEIGHT_VALUE': '148',
#      'SEX_TYPE': 'M',
#      'DAYS_SINCE_LAST_RUN': '19',
#      'WEARING': 'Tongue strap',
#      'OWNER_NAME': 'Mr Ricki Vaughan',
#      'DAM_YEAR_BORN': '2012',
#      'SIRE_BRED': 'GBR',
#      'JOCKEY_NAME': 'N F Houlihan',
#      'DAM_BRED': 'GBR',
#      'ADJUSTED_RATING': None,
#      'runnerId': '41192922',
#      'CLOTH_NUMBER': '7',
#      'SIRE_YEAR_BORN': '2003',
#      'TRAINER_NAME': 'Miss S West',
#      'COLOUR_TYPE': 'b',
#      'AGE': '5',
#      'DAMSIRE_BRED': 'GBR',
#      'JOCKEY_CLAIM': '3',
#      'FORM': '7/P64P-7',
#      'FORECASTPRICE_NUMERATOR': '16',
#      'BRED': None,
#      'DAM_NAME': 'Follow The Faith',
#      'DAMSIRE_YEAR_BORN': '1991',
#      'STALL_DRAW': None,
#      'WEIGHT_UNITS': 'pounds'}},
#    {'selectionId': 39716173,
#     'runnerName': 'Saved By The River',
#     'handicap': 0.0,
#     'sortPriority': 8,
#     'metadata': {'SIRE_NAME': 'Hallowed Crown',
#      'CLOTH_NUMBER_ALPHA': '6',
#      'OFFICIAL_RATING': '80',
#      'COLOURS_DESCRIPTION': 'Yellow, green striped sleeves, yellow cap',
#      'COLOURS_FILENAME': 'c20230616fon/00010133.jpg',
#      'FORECASTPRICE_DENOMINATOR': '1',
#      'DAMSIRE_NAME': 'Desert Prince',
#      'WEIGHT_VALUE': '148',
#      'SEX_TYPE': 'G',
#      'DAYS_SINCE_LAST_RUN': '27',
#      'WEARING': None,
#      'OWNER_NAME': 'Mr Seamus Mullins',
#      'DAM_YEAR_BORN': '0',
#      'SIRE_BRED': 'AUS',
#      'JOCKEY_NAME': 'Daniel Sansom',
#      'DAM_BRED': 'IRL',
#      'ADJUSTED_RATING': None,
#      'runnerId': '39716173',
#      'CLOTH_NUMBER': '6',
#      'SIRE_YEAR_BORN': '2011',
#      'TRAINER_NAME': 'J W Mullins',
#      'COLOUR_TYPE': 'b',
#      'AGE': '6',
#      'DAMSIRE_BRED': 'IRL',
#      'JOCKEY_CLAIM': '3',
#      'FORM': '09U4P-6',
#      'FORECASTPRICE_NUMERATOR': '33',
#      'BRED': None,
#      'DAM_NAME': 'Mataji',
#      'DAMSIRE_YEAR_BORN': '1995',
#      'STALL_DRAW': None,
#      'WEIGHT_UNITS': 'pounds'}}]},
#  {'marketId': '1.215236458',
#   'marketName': '7f Stks',
#   'totalMatched': 1791.31,
#   'runners': [{'selectionId': 17897792,
#     'runnerName': 'Pretreville',
#     'handicap': 0.0,
#     'sortPriority': 1,
#     'metadata': {'SIRE_NAME': 'Acclamation',
#      'CLOTH_NUMBER_ALPHA': '2',
#      'OFFICIAL_RATING': None,
#      'COLOURS_DESCRIPTION': 'White and orange halved, emerald green sleeves, white stars, white cap, emerald green stars',
#      'COLOURS_FILENAME': 'c20230616fai/00869956.jpg',
#      'FORECASTPRICE_DENOMINATOR': '8',
#      'DAMSIRE_NAME': 'Fusaichi Pegasus',
#      'WEIGHT_VALUE': '137',
#      'SEX_TYPE': 'g',
#      'DAYS_SINCE_LAST_RUN': '356',
#      'WEARING': None,
#      'OWNER_NAME': 'ShamrockThoroughbreds&GAugustin-Normand',
#      'DAM_YEAR_BORN': '2006',
#      'SIRE_BRED': 'UK',
#      'JOCKEY_NAME': 'C. J. MacRedmond',
#      'DAM_BRED': 'USA',
#      'ADJUSTED_RATING': None,
#      'runnerId': '17897792',
#      'CLOTH_NUMBER': '2',
#      'SIRE_YEAR_BORN': '1999',
#      'TRAINER_NAME': 'Adrian McGuinness',
#      'COLOUR_TYPE': 'b',
#      'AGE': '8',
#      'DAMSIRE_BRED': 'USA',
#      'JOCKEY_CLAIM': '5',
#      'FORM': '122135-',
#      'FORECASTPRICE_NUMERATOR': '11',
#      'BRED': 'FR',
#      'DAM_NAME': 'Pegase Hurry',
#      'DAMSIRE_YEAR_BORN': '1997',
#      'STALL_DRAW': '1',
#      'WEIGHT_UNITS': 'pounds'}},
#    {'selectionId': 29291861,
#     'runnerName': 'Monaasib',
#     'handicap': 0.0,
#     'sortPriority': 2,
#     'metadata': {'SIRE_NAME': "Bobby's Kitten",
#      'CLOTH_NUMBER_ALPHA': '1',
#      'OFFICIAL_RATING': '103',
#      'COLOURS_DESCRIPTION': 'Navy blue, white stripes, scarlet seams and buttons, navy, scarlet and white quartered cap',
#      'COLOURS_FILENAME': 'c20230616fai/00862148.jpg',
#      'FORECASTPRICE_DENOMINATOR': '4',
#      'DAMSIRE_NAME': 'Oasis Dream',
#      'WEIGHT_VALUE': '137',
#      'SEX_TYPE': 'g',
#      'DAYS_SINCE_LAST_RUN': '26',
#      'WEARING': 'tongue strap',
#      'OWNER_NAME': 'Kevin Prendergast',
#      'DAM_YEAR_BORN': '2005',
#      'SIRE_BRED': 'USA',
#      'JOCKEY_NAME': 'S. McCullagh',
#      'DAM_BRED': 'UK',
#      'ADJUSTED_RATING': '0',
#      'runnerId': '29291861',
#      'CLOTH_NUMBER': '1',
#      'SIRE_YEAR_BORN': '2011',
#      'TRAINER_NAME': 'Kevin Prendergast',
#      'COLOUR_TYPE': 'b',
#      'AGE': '5',
#      'DAMSIRE_BRED': 'UK',
#      'JOCKEY_CLAIM': '3',
#      'FORM': '5220-36',
#      'FORECASTPRICE_NUMERATOR': '11',
#      'BRED': 'GB',
#      'DAM_NAME': 'Mullein',
#      'DAMSIRE_YEAR_BORN': '2000',
#      'STALL_DRAW': '4',
#      'WEIGHT_UNITS': 'pounds'}},
#    {'selectionId': 10849837,
#     'runnerName': 'Affogato',
#     'handicap': 0.0,
#     'sortPriority': 3,
#     'metadata': {'SIRE_NAME': 'Requinto',
#      'CLOTH_NUMBER_ALPHA': '3',
#      'OFFICIAL_RATING': '97',
#      'COLOURS_DESCRIPTION': 'Maroon, white seams, striped sleeves, maroon cap',
#      'COLOURS_FILENAME': 'c20230616fai/00863069.jpg',
#      'FORECASTPRICE_DENOMINATOR': '2',
#      'DAMSIRE_NAME': 'Bahamian Bounty',
#      'WEIGHT_VALUE': '132',
#      'SEX_TYPE': 'f',
#      'DAYS_SINCE_LAST_RUN': '11',
#      'WEARING': None,
#      'OWNER_NAME': 'Ray Grehan',
#      'DAM_YEAR_BORN': '2010',
#      'SIRE_BRED': 'IRE',
#      'JOCKEY_NAME': 'J. J. G. Ryan',
#      'DAM_BRED': 'UK',
#      'ADJUSTED_RATING': '0',
#      'runnerId': '10849837',
#      'CLOTH_NUMBER': '3',
#      'SIRE_YEAR_BORN': '2009',
#      'TRAINER_NAME': 'G. M. Lyons',
#      'COLOUR_TYPE': 'b',
#      'AGE': '4',
#      'DAMSIRE_BRED': 'UK',
#      'JOCKEY_CLAIM': '7',
#      'FORM': '6660-87',
#      'FORECASTPRICE_NUMERATOR': '7',
#      'BRED': 'IRE',
#      'DAM_NAME': 'Miss Mocca',
#      'DAMSIRE_YEAR_BORN': '1994',
#      'STALL_DRAW': '3',
#      'WEIGHT_UNITS': 'pounds'}},
#    {'selectionId': 6942596,
#     'runnerName': 'Vernet',
#     'handicap': 0.0,
#     'sortPriority': 4,
#     'metadata': {'SIRE_NAME': 'Caravaggio',
#      'CLOTH_NUMBER_ALPHA': '4',
#      'OFFICIAL_RATING': '87',
#      'COLOURS_DESCRIPTION': 'Light blue and yellow check, yellow and white striped sleeves, light blue and yellow quartered cap',
#      'COLOURS_FILENAME': 'c20230616fai/00015305.jpg',
#      'FORECASTPRICE_DENOMINATOR': '1',
#      'DAMSIRE_NAME': 'Anabaa',
#      'WEIGHT_VALUE': '126',
#      'SEX_TYPE': 'f',
#      'DAYS_SINCE_LAST_RUN': '23',
#      'WEARING': None,
#      'OWNER_NAME': 'Mr John C. Oxley',
#      'DAM_YEAR_BORN': '2005',
#      'SIRE_BRED': 'USA',
#      'JOCKEY_NAME': 'H. J. Horgan',
#      'DAM_BRED': 'FR',
#      'ADJUSTED_RATING': '0',
#      'runnerId': '6942596',
#      'CLOTH_NUMBER': '4',
#      'SIRE_YEAR_BORN': '2014',
#      'TRAINER_NAME': "Joseph Patrick O'Brien",
#      'COLOUR_TYPE': 'b',
#      'AGE': '3',
#      'DAMSIRE_BRED': 'USA',
#      'JOCKEY_CLAIM': '7',
#      'FORM': '417-6',
#      'FORECASTPRICE_NUMERATOR': '9',
#      'BRED': 'IRE',
#      'DAM_NAME': 'Morning Line',
#      'DAMSIRE_YEAR_BORN': '1992',
#      'STALL_DRAW': '2',
#      'WEIGHT_UNITS': 'pounds'}}]},
#  {'marketId': '1.215231870',
#   'marketName': '2m4f Hcap Chs',
#   'totalMatched': 10775.68,
#   'runners': [{'selectionId': 42184135,
#     'runnerName': 'Post No Bills',
#     'handicap': 0.0,
#     'sortPriority': 1,
#     'metadata': {'SIRE_NAME': 'Mahler',
#      'CLOTH_NUMBER_ALPHA': '8',
#      'OFFICIAL_RATING': '111',
#      'COLOURS_DESCRIPTION': 'Emerald green, light green star and star on cap',
#      'COLOURS_FILENAME': 'c20230616ain/00871394A.jpg',
#      'FORECASTPRICE_DENOMINATOR': '8',
#      'DAMSIRE_NAME': 'Moscow Society',
#      'WEIGHT_VALUE': '154',
#      'SEX_TYPE': 'G',
#      'DAYS_SINCE_LAST_RUN': '16',
#      'WEARING': None,
#      'OWNER_NAME': 'Pyne Swinburne Partnership',
#      'DAM_YEAR_BORN': '1999',
#      'SIRE_BRED': 'GBR',
#      'JOCKEY_NAME': 'S Bowen',
#      'DAM_BRED': 'IRL',
#      'ADJUSTED_RATING': None,
#      'runnerId': '42184135',
#      'CLOTH_NUMBER': '8',
#      'SIRE_YEAR_BORN': '1990',
#      'TRAINER_NAME': 'R Potter',
#      'COLOUR_TYPE': 'b',
#      'AGE': '8',
#      'DAMSIRE_BRED': 'USA',
#      'JOCKEY_CLAIM': '0',
#      'FORM': '2822-11',
#      'FORECASTPRICE_NUMERATOR': '11',
#      'BRED': None,
#      'DAM_NAME': 'Shining Lights',
#      'DAMSIRE_YEAR_BORN': '1985',
#      'STALL_DRAW': None,
#      'WEIGHT_UNITS': 'pounds'}},
#    {'selectionId': 15729592,
#     'runnerName': 'Cracking Destiny',
#     'handicap': 0.0,
#     'sortPriority': 2,
#     'metadata': {'SIRE_NAME': 'Dubai Destination',
#      'CLOTH_NUMBER_ALPHA': '5',
#      'OFFICIAL_RATING': '121',
#      'COLOURS_DESCRIPTION': 'Black, pink star, pink and black check sleeves, pink cap, black stars',
#      'COLOURS_FILENAME': 'c20230616ain/00878993.jpg',
#      'FORECASTPRICE_DENOMINATOR': '1',
#      'DAMSIRE_NAME': 'Alderbrook',
#      'WEIGHT_VALUE': '164',
#      'SEX_TYPE': 'G',
#      'DAYS_SINCE_LAST_RUN': '37',
#      'WEARING': None,
#      'OWNER_NAME': 'Mrs Louise Whillans & King for a Day',
#      'DAM_YEAR_BORN': '2006',
#      'SIRE_BRED': 'USA',
#      'JOCKEY_NAME': 'B S Hughes',
#      'DAM_BRED': 'IRL',
#      'ADJUSTED_RATING': None,
#      'runnerId': '15729592',
#      'CLOTH_NUMBER': '5',
#      'SIRE_YEAR_BORN': '1999',
#      'TRAINER_NAME': 'Ewan Whillans',
#      'COLOUR_TYPE': 'b',
#      'AGE': '10',
#      'DAMSIRE_BRED': 'GBR',
#      'JOCKEY_CLAIM': '0',
#      'FORM': '247/64-3',
#      'FORECASTPRICE_NUMERATOR': '10',
#      'BRED': None,
#      'DAM_NAME': 'Cracking Gale',
#      'DAMSIRE_YEAR_BORN': '1989',
#      'STALL_DRAW': None,
#      'WEIGHT_UNITS': 'pounds'}},
#    {'selectionId': 15926502,
#     'runnerName': 'The Big Lense',
#     'handicap': 0.0,
#     'sortPriority': 3,
#     'metadata': {'SIRE_NAME': 'Court Cave',
#      'CLOTH_NUMBER_ALPHA': '1',
#      'OFFICIAL_RATING': '125',
#      'COLOURS_DESCRIPTION': 'White, black diamonds on sleeves, check cap',
#      'COLOURS_FILENAME': 'c20230616ain/00877915.jpg',
#      'FORECASTPRICE_DENOMINATOR': '1',
#      'DAMSIRE_NAME': 'Supreme Leader',
#      'WEIGHT_VALUE': '168',
#      'SEX_TYPE': 'G',
#      'DAYS_SINCE_LAST_RUN': '23',
#      'WEARING': 'Tongue strap,Cheek pieces',
#      'OWNER_NAME': 'The Gary Allsopp Partnership',
#      'DAM_YEAR_BORN': '2002',
#      'SIRE_BRED': 'IRL',
#      'JOCKEY_NAME': 'Mr Alex Chadwick',
#      'DAM_BRED': 'IRL',
#      'ADJUSTED_RATING': None,
#      'runnerId': '15926502',
#      'CLOTH_NUMBER': '1',
#      'SIRE_YEAR_BORN': '0',
#      'TRAINER_NAME': 'James Owen',
#      'COLOUR_TYPE': 'b',
#      'AGE': '10',
#      'DAMSIRE_BRED': 'GBR',
#      'JOCKEY_CLAIM': '7',
#      'FORM': '7264-34',
#      'FORECASTPRICE_NUMERATOR': '8',
#      'BRED': None,
#      'DAM_NAME': 'Megans Joy',
#      'DAMSIRE_YEAR_BORN': '1982',
#      'STALL_DRAW': None,
#      'WEIGHT_UNITS': 'pounds'}},
#    {'selectionId': 26578369,
#     'runnerName': 'De Barley Basket',
#     'handicap': 0.0,
#     'sortPriority': 4,
#     'metadata': {'SIRE_NAME': 'Alkaadhem',
#      'CLOTH_NUMBER_ALPHA': '2',
#      'OFFICIAL_RATING': None,
#      'COLOURS_DESCRIPTION': 'Navy blue, pink and green sash and hooped cap',
#      'COLOURS_FILENAME': 'c20230616ain/00860078A.jpg',
#      'FORECASTPRICE_DENOMINATOR': '1',
#      'DAMSIRE_NAME': 'Mandalus',
#      'WEIGHT_VALUE': '167',
#      'SEX_TYPE': 'G',
#      'DAYS_SINCE_LAST_RUN': '18',
#      'WEARING': 'Tongue strap',
#      'OWNER_NAME': 'Mrs S N J Embiricos & Ms A Embiricos',
#      'DAM_YEAR_BORN': '1996',
#      'SIRE_BRED': 'GBR',
#      'JOCKEY_NAME': 'Kielan Woods',
#      'DAM_BRED': 'IRL',
#      'ADJUSTED_RATING': None,
#      'runnerId': '26578369',
#      'CLOTH_NUMBER': '2',
#      'SIRE_YEAR_BORN': '2000',
#      'TRAINER_NAME': 'B Pauling',
#      'COLOUR_TYPE': 'b',
#      'AGE': '10',
#      'DAMSIRE_BRED': 'GBR',
#      'JOCKEY_CLAIM': '0',
#      'FORM': 'P31U2-3',
#      'FORECASTPRICE_NUMERATOR': '6',
#      'BRED': None,
#      'DAM_NAME': 'Lady Willmurt',
#      'DAMSIRE_YEAR_BORN': '0',
#      'STALL_DRAW': None,
#      'WEIGHT_UNITS': 'pounds'}},
#    {'selectionId': 20606726,
#     'runnerName': 'Politicise',
#     'handicap': 0.0,
#     'sortPriority': 5,
#     'metadata': {'SIRE_NAME': 'Camelot',
#      'CLOTH_NUMBER_ALPHA': '7',
#      'OFFICIAL_RATING': None,
#      'COLOURS_DESCRIPTION': 'Red, black seams, black and white check sleeves, white cap',
#      'COLOURS_FILENAME': 'c20230616ain/00876095.jpg',
#      'FORECASTPRICE_DENOMINATOR': '1',
#      'DAMSIRE_NAME': 'Barathea',
#      'WEIGHT_VALUE': '157',
#      'SEX_TYPE': 'G',
#      'DAYS_SINCE_LAST_RUN': '32',
#      'WEARING': 'Cheek pieces',
#      'OWNER_NAME': 'De Bad Back Syndicate',
#      'DAM_YEAR_BORN': '0',
#      'SIRE_BRED': 'GBR',
#      'JOCKEY_NAME': 'Jack Hogan',
#      'DAM_BRED': 'USA',
#      'ADJUSTED_RATING': None,
#      'runnerId': '20606726',
#      'CLOTH_NUMBER': '7',
#      'SIRE_YEAR_BORN': '1999',
#      'TRAINER_NAME': 'N Slevin',
#      'COLOUR_TYPE': 'b',
#      'AGE': '7',
#      'DAMSIRE_BRED': 'IRL',
#      'JOCKEY_CLAIM': '5',
#      'FORM': '0546-26',
#      'FORECASTPRICE_NUMERATOR': '4',
#      'BRED': None,
#      'DAM_NAME': 'Politesse',
#      'DAMSIRE_YEAR_BORN': '1990',
#      'STALL_DRAW': None,
# ...
#      'COLOURS_DESCRIPTION': 'White, royal blue stars and armlets, white cap, orange star',
#      'COLOURS_FILENAME': 'c20230617lei/00878830.jpg',
#      'FORECASTPRICE_DENOMINATOR': '1',
#      'DAMSIRE_NAME': 'Elusive Pimpernel',
#      'WEIGHT_VALUE': '133',
#      'SEX_TYPE': 'G',
#      'DAYS_SINCE_LAST_RUN': '0',
#      'WEARING': None,
#      'OWNER_NAME': 'R Jarrett',
#      'DAM_YEAR_BORN': '2013',
#      'SIRE_BRED': 'GBR',
#      'JOCKEY_NAME': 'D C Costello',
#      'DAM_BRED': 'IRL',
#      'ADJUSTED_RATING': None,
#      'runnerId': '334665',
#      'CLOTH_NUMBER': '7',
#      'SIRE_YEAR_BORN': '2014',
#      'TRAINER_NAME': 'R Harris',
#      'COLOUR_TYPE': 'b',
#      'AGE': '2',
#      'DAMSIRE_BRED': 'USA',
#      'JOCKEY_CLAIM': '0',
#      'FORM': None,
#      'FORECASTPRICE_NUMERATOR': '33',
#      'BRED': None,
#      'DAM_NAME': 'Mollies Girl',
#      'DAMSIRE_YEAR_BORN': '2007',
#      'STALL_DRAW': '5',
#      'WEIGHT_UNITS': 'pounds'}},
#    {'selectionId': 57154466,
#     'runnerName': 'Pour La Vie',
#     'handicap': 0.0,
#     'sortPriority': 8,
#     'metadata': {'SIRE_NAME': 'Time Test',
#      'CLOTH_NUMBER_ALPHA': '10',
#      'OFFICIAL_RATING': None,
#      'COLOURS_DESCRIPTION': 'Purple, white hoop, hooped sleeves',
#      'COLOURS_FILENAME': 'c20230617lei/00878600.jpg',
#      'FORECASTPRICE_DENOMINATOR': '1',
#      'DAMSIRE_NAME': 'Cockney Rebel',
#      'WEIGHT_VALUE': '128',
#      'SEX_TYPE': 'F',
#      'DAYS_SINCE_LAST_RUN': '0',
#      'WEARING': None,
#      'OWNER_NAME': 'Mrs Giselle De Aguiar',
#      'DAM_YEAR_BORN': '2009',
#      'SIRE_BRED': 'GBR',
#      'JOCKEY_NAME': 'Christian Howarth',
#      'DAM_BRED': 'GBR',
#      'ADJUSTED_RATING': None,
#      'runnerId': '57154466',
#      'CLOTH_NUMBER': '10',
#      'SIRE_YEAR_BORN': '2012',
#      'TRAINER_NAME': 'Alice Haynes',
#      'COLOUR_TYPE': 'b',
#      'AGE': '2',
#      'DAMSIRE_BRED': 'IRL',
#      'JOCKEY_CLAIM': '5',
#      'FORM': None,
#      'FORECASTPRICE_NUMERATOR': '20',
#      'BRED': None,
#      'DAM_NAME': 'Rockme Cockney',
#      'DAMSIRE_YEAR_BORN': '2004',
#      'STALL_DRAW': '12',
#      'WEIGHT_UNITS': 'pounds'}},
#    {'selectionId': 57154467,
#     'runnerName': 'Chriss Mate',
#     'handicap': 0.0,
#     'sortPriority': 9,
#     'metadata': {'SIRE_NAME': 'Washington Dc',
#      'CLOTH_NUMBER_ALPHA': '1',
#      'OFFICIAL_RATING': None,
#      'COLOURS_DESCRIPTION': 'White, royal blue triple diamond, white and red striped sleeves, royal blue cap, white spots',
#      'COLOURS_FILENAME': 'c20230617lei/00861932.jpg',
#      'FORECASTPRICE_DENOMINATOR': '1',
#      'DAMSIRE_NAME': 'Firebreak',
#      'WEIGHT_VALUE': '133',
#      'SEX_TYPE': 'C',
#      'DAYS_SINCE_LAST_RUN': '0',
#      'WEARING': None,
#      'OWNER_NAME': 'Cross Channel Racing And Partner',
#      'DAM_YEAR_BORN': '2013',
#      'SIRE_BRED': 'IRL',
#      'JOCKEY_NAME': 'Dylan Hogan',
#      'DAM_BRED': 'GBR',
#      'ADJUSTED_RATING': None,
#      'runnerId': '57154467',
#      'CLOTH_NUMBER': '1',
#      'SIRE_YEAR_BORN': '2013',
#      'TRAINER_NAME': 'R Brisland',
#      'COLOUR_TYPE': 'b',
#      'AGE': '2',
#      'DAMSIRE_BRED': 'GBR',
#      'JOCKEY_CLAIM': '0',
#      'FORM': None,
#      'FORECASTPRICE_NUMERATOR': '50',
#      'BRED': None,
#      'DAM_NAME': 'Seaperle',
#      'DAMSIRE_YEAR_BORN': '1999',
#      'STALL_DRAW': '1',
#      'WEIGHT_UNITS': 'pounds'}},
#    {'selectionId': 57154465,
#     'runnerName': 'Tees Comet',
#     'handicap': 0.0,
#     'sortPriority': 10,
#     'metadata': {'SIRE_NAME': 'Zoustar',
#      'CLOTH_NUMBER_ALPHA': '11',
#      'OFFICIAL_RATING': None,
#      'COLOURS_DESCRIPTION': 'Turquoise with black striped cap',
#      'COLOURS_FILENAME': 'c20230617lei/00835566B.jpg',
#      'FORECASTPRICE_DENOMINATOR': '1',
#      'DAMSIRE_NAME': 'Dubawi',
#      'WEIGHT_VALUE': '128',
#      'SEX_TYPE': 'F',
#      'DAYS_SINCE_LAST_RUN': '0',
#      'WEARING': None,
#      'OWNER_NAME': 'Ingleby Bloodstock Limited',
#      'DAM_YEAR_BORN': '2014',
#      'SIRE_BRED': 'AUS',
#      'JOCKEY_NAME': 'Barry McHugh',
#      'DAM_BRED': 'GBR',
#      'ADJUSTED_RATING': None,
#      'runnerId': '57154465',
#      'CLOTH_NUMBER': '11',
#      'SIRE_YEAR_BORN': '2010',
#      'TRAINER_NAME': 'Adrian Nicholls',
#      'COLOUR_TYPE': 'b',
#      'AGE': '2',
#      'DAMSIRE_BRED': 'IRL',
#      'JOCKEY_CLAIM': '0',
#      'FORM': None,
#      'FORECASTPRICE_NUMERATOR': '33',
#      'BRED': None,
#      'DAM_NAME': 'Dubara',
#      'DAMSIRE_YEAR_BORN': '2002',
#      'STALL_DRAW': '2',
#      'WEIGHT_UNITS': 'pounds'}},
#    {'selectionId': 54618158,
#     'runnerName': 'Golden Bungle',
#     'handicap': 0.0,
#     'sortPriority': 11,
#     'metadata': {'SIRE_NAME': 'Kuroshio',
#      'CLOTH_NUMBER_ALPHA': '9',
#      'OFFICIAL_RATING': '0',
#      'COLOURS_DESCRIPTION': 'Yellow, black braces, black sleeves, yellow armlets, striped cap',
#      'COLOURS_FILENAME': 'c20230617lei/00038976A.jpg',
#      'FORECASTPRICE_DENOMINATOR': '1',
#      'DAMSIRE_NAME': 'Montjeu',
#      'WEIGHT_VALUE': '128',
#      'SEX_TYPE': 'F',
#      'DAYS_SINCE_LAST_RUN': '66',
#      'WEARING': None,
#      'OWNER_NAME': 'Mr W P Flynn',
#      'DAM_YEAR_BORN': '2013',
#      'SIRE_BRED': 'AUS',
#      'JOCKEY_NAME': 'Ray Dawson',
#      'DAM_BRED': 'IRL',
#      'ADJUSTED_RATING': None,
#      'runnerId': '54618158',
#      'CLOTH_NUMBER': '9',
#      'SIRE_YEAR_BORN': '2010',
#      'TRAINER_NAME': 'I Furtado',
#      'COLOUR_TYPE': 'b',
#      'AGE': '2',
#      'DAMSIRE_BRED': 'IRL',
#      'JOCKEY_CLAIM': '0',
#      'FORM': '6',
#      'FORECASTPRICE_NUMERATOR': '33',
#      'BRED': None,
#      'DAM_NAME': 'Gold Bracelet',
#      'DAMSIRE_YEAR_BORN': '1996',
#      'STALL_DRAW': '11',
#      'WEIGHT_UNITS': 'pounds'}},
#    {'selectionId': 56881073,
#     'runnerName': 'Unleash Hell',
#     'handicap': 0.0,
#     'sortPriority': 12,
#     'metadata': {'SIRE_NAME': 'Postponed',
#      'CLOTH_NUMBER_ALPHA': '6',
#      'OFFICIAL_RATING': '0',
#      'COLOURS_DESCRIPTION': 'Royal blue, white stripe, red sleeves and cap',
#      'COLOURS_FILENAME': 'c20230617lei/00878833.jpg',
#      'FORECASTPRICE_DENOMINATOR': '1',
#      'DAMSIRE_NAME': 'Iffraaj',
#      'WEIGHT_VALUE': '133',
#      'SEX_TYPE': 'C',
#      'DAYS_SINCE_LAST_RUN': '8',
#      'WEARING': None,
#      'OWNER_NAME': 'Tom Dascombe Racing Club & Mrs Kavanag',
#      'DAM_YEAR_BORN': '2015',
#      'SIRE_BRED': 'IRL',
#      'JOCKEY_NAME': 'L P Keniry',
#      'DAM_BRED': 'IRL',
#      'ADJUSTED_RATING': None,
#      'runnerId': '56881073',
#      'CLOTH_NUMBER': '6',
#      'SIRE_YEAR_BORN': '2011',
#      'TRAINER_NAME': 'Tom Dascombe',
#      'COLOUR_TYPE': 'b',
#      'AGE': '2',
#      'DAMSIRE_BRED': 'GBR',
#      'JOCKEY_CLAIM': '0',
#      'FORM': '7',
#      'FORECASTPRICE_NUMERATOR': '33',
#      'BRED': None,
#      'DAM_NAME': 'Serabrina',
#      'DAMSIRE_YEAR_BORN': '2001',
#      'STALL_DRAW': '6',
#      'WEIGHT_UNITS': 'pounds'}},
#    {'selectionId': 169208,
#     'runnerName': 'Timetobenice',
#     'handicap': 0.0,
#     'sortPriority': 13,
#     'metadata': {'SIRE_NAME': 'Time Test',
#      'CLOTH_NUMBER_ALPHA': '5',
#      'OFFICIAL_RATING': None,
#      'COLOURS_DESCRIPTION': 'Red, emerald green and red diabolo on sleeves, emerald green cap',
#      'COLOURS_FILENAME': 'c20230617lei/00850508.jpg',
#      'FORECASTPRICE_DENOMINATOR': '1',
#      'DAMSIRE_NAME': 'Galileo',
#      'WEIGHT_VALUE': '133',
#      'SEX_TYPE': 'C',
#      'DAYS_SINCE_LAST_RUN': '0',
#      'WEARING': None,
#      'OWNER_NAME': 'Mr Raymond Treacy',
#      'DAM_YEAR_BORN': '1990',
#      'SIRE_BRED': 'GBR',
#      'JOCKEY_NAME': 'Ben Robinson',
#      'DAM_BRED': 'IRL',
#      'ADJUSTED_RATING': None,
#      'runnerId': '169208',
#      'CLOTH_NUMBER': '5',
#      'SIRE_YEAR_BORN': '2012',
#      'TRAINER_NAME': "D O'Meara",
#      'COLOUR_TYPE': 'b',
#      'AGE': '2',
#      'DAMSIRE_BRED': 'IRL',
#      'JOCKEY_CLAIM': '0',
#      'FORM': None,
#      'FORECASTPRICE_NUMERATOR': '25',
#      'BRED': None,
#      'DAM_NAME': 'Station House',
#      'DAMSIRE_YEAR_BORN': '1998',
#      'STALL_DRAW': '4',
#      'WEIGHT_UNITS': 'pounds'}}]},
#  {'marketId': '1.215251981',
#   'marketName': '3m Nov Hcap Chs',
#   'totalMatched': 20.0,
#   'runners': [{'selectionId': 42405269,
#     'runnerName': 'Carlo Du Berlais',
#     'handicap': 0.0,
#     'sortPriority': 1,
#     'metadata': {'SIRE_NAME': 'Carlotamix',
#      'CLOTH_NUMBER_ALPHA': '1',
#      'OFFICIAL_RATING': None,
#      'COLOURS_DESCRIPTION': 'Mauve, black chevrons on sleeves, black cap',
#      'COLOURS_FILENAME': 'c20230617utt/00870080.jpg',
#      'FORECASTPRICE_DENOMINATOR': '4',
#      'DAMSIRE_NAME': 'Flemensfirth',
#      'WEIGHT_VALUE': '168',
#      'SEX_TYPE': 'G',
#      'DAYS_SINCE_LAST_RUN': '42',
#      'WEARING': 'Cheek pieces',
#      'OWNER_NAME': 'Owners Group 089',
#      'DAM_YEAR_BORN': '0',
#      'SIRE_BRED': 'FRA',
#      'JOCKEY_NAME': 'C Brace',
#      'DAM_BRED': 'IRL',
#      'ADJUSTED_RATING': None,
#      'runnerId': '42405269',
#      'CLOTH_NUMBER': '1',
#      'SIRE_YEAR_BORN': '2003',
#      'TRAINER_NAME': "F O'Brien",
#      'COLOUR_TYPE': 'b',
#      'AGE': '6',
#      'DAMSIRE_BRED': 'USA',
#      'JOCKEY_CLAIM': '0',
#      'FORM': '56/876-1',
#      'FORECASTPRICE_NUMERATOR': '9',
#      'BRED': None,
#      'DAM_NAME': 'Dark Ebony',
#      'DAMSIRE_YEAR_BORN': '1992',
#      'STALL_DRAW': None,
#      'WEIGHT_UNITS': 'pounds'}},
#    {'selectionId': 38348751,
#     'runnerName': 'Present Storm',
#     'handicap': 0.0,
#     'sortPriority': 2,
#     'metadata': {'SIRE_NAME': 'Presenting',
#      'CLOTH_NUMBER_ALPHA': '2',
#      'OFFICIAL_RATING': '96',
#      'COLOURS_DESCRIPTION': 'Orange, dark blue triple diamond',
#      'COLOURS_FILENAME': 'c20230617utt/00071917.jpg',
#      'FORECASTPRICE_DENOMINATOR': '1',
#      'DAMSIRE_NAME': 'Glacial Storm',
#      'WEIGHT_VALUE': '167',
#      'SEX_TYPE': 'M',
#      'DAYS_SINCE_LAST_RUN': '40',
#      'WEARING': 'Cheek pieces,Tongue strap',
#      'OWNER_NAME': 'Mr Robert Aplin',
#      'DAM_YEAR_BORN': '1998',
#      'SIRE_BRED': 'GBR',
#      'JOCKEY_NAME': 'B S Hughes',
#      'DAM_BRED': 'IRL',
#      'ADJUSTED_RATING': None,
#      'runnerId': '38348751',
#      'CLOTH_NUMBER': '2',
#      'SIRE_YEAR_BORN': '1992',
#      'TRAINER_NAME': 'C E Longsdon',
#      'COLOUR_TYPE': 'b',
#      'AGE': '7',
#      'DAMSIRE_BRED': 'USA',
#      'JOCKEY_CLAIM': '0',
#      'FORM': '712P7-3',
#      'FORECASTPRICE_NUMERATOR': '4',
#      'BRED': None,
#      'DAM_NAME': 'Sunami Storm',
#      'DAMSIRE_YEAR_BORN': '1985',
#      'STALL_DRAW': None,
#      'WEIGHT_UNITS': 'pounds'}},
#    {'selectionId': 21822171,
#     'runnerName': 'Dorado Dollar',
#     'handicap': 0.0,
#     'sortPriority': 3,
#     'metadata': {'SIRE_NAME': 'Golden Lariat',
#      'CLOTH_NUMBER_ALPHA': '6',
#      'OFFICIAL_RATING': '76',
#      'COLOURS_DESCRIPTION': 'Orange, yellow star, orange sleeves, yellow stars',
#      'COLOURS_FILENAME': 'c20230617utt/00862117.jpg',
#      'FORECASTPRICE_DENOMINATOR': '1',
#      'DAMSIRE_NAME': 'Old Vic',
#      'WEIGHT_VALUE': '147',
#      'SEX_TYPE': 'G',
#      'DAYS_SINCE_LAST_RUN': '24',
#      'WEARING': 'Cheek pieces',
#      'OWNER_NAME': 'Miss Pat Murray',
#      'DAM_YEAR_BORN': '0',
#      'SIRE_BRED': 'USA',
#      'JOCKEY_NAME': 'Harry Bannister',
#      'DAM_BRED': 'IRL',
#      'ADJUSTED_RATING': None,
#      'runnerId': '21822171',
#      'CLOTH_NUMBER': '6',
#      'SIRE_YEAR_BORN': '1999',
#      'TRAINER_NAME': 'B I Case',
#      'COLOUR_TYPE': 'ch',
#      'AGE': '9',
#      'DAMSIRE_BRED': 'GBR',
#      'JOCKEY_CLAIM': '0',
#      'FORM': '3PP2-24',
#      'FORECASTPRICE_NUMERATOR': '5',
#      'BRED': None,
#      'DAM_NAME': 'Stability Treaty',
#      'DAMSIRE_YEAR_BORN': '1986',
#      'STALL_DRAW': None,
#      'WEIGHT_UNITS': 'pounds'}},
#    {'selectionId': 27772068,
#     'runnerName': 'Methodtothemagic',
#     'handicap': 0.0,
#     'sortPriority': 4,
#     'metadata': {'SIRE_NAME': 'Sans Frontieres',
#      'CLOTH_NUMBER_ALPHA': '4',
#      'OFFICIAL_RATING': None,
#      'COLOURS_DESCRIPTION': 'Dark blue, white cross belts, light blue sleeves and cap',
#      'COLOURS_FILENAME': 'c20230617utt/00861609.jpg',
#      'FORECASTPRICE_DENOMINATOR': '1',
#      'DAMSIRE_NAME': 'Shernazar',
#      'WEIGHT_VALUE': '159',
#      'SEX_TYPE': 'M',
#      'DAYS_SINCE_LAST_RUN': '68',
#      'WEARING': None,
#      'OWNER_NAME': 'Dalziel Family, T White, J Inverdale',
#      'DAM_YEAR_BORN': '2001',
#      'SIRE_BRED': 'IRL',
#      'JOCKEY_NAME': 'Thomas Bellamy',
#      'DAM_BRED': 'IRL',
#      'ADJUSTED_RATING': None,
#      'runnerId': '27772068',
#      'CLOTH_NUMBER': '4',
#      'SIRE_YEAR_BORN': '2006',
#      'TRAINER_NAME': 'R T Phillips',
#      'COLOUR_TYPE': 'b',
#      'AGE': '8',
#      'DAMSIRE_BRED': 'GBR',
#      'JOCKEY_CLAIM': '0',
#      'FORM': '003663-',
#      'FORECASTPRICE_NUMERATOR': '6',
#      'BRED': None,
#      'DAM_NAME': 'Cindys Fancy',
#      'DAMSIRE_YEAR_BORN': '1981',
#      'STALL_DRAW': None,
#      'WEIGHT_UNITS': 'pounds'}},
#    {'selectionId': 51418306,
#     'runnerName': 'Presenting Belle',
#     'handicap': 0.0,
#     'sortPriority': 5,
#     'metadata': {'SIRE_NAME': 'Valirann',
#      'CLOTH_NUMBER_ALPHA': '3',
#      'OFFICIAL_RATING': '92',
#      'COLOURS_DESCRIPTION': 'Emerald green and red (quartered), emerald green sleeves, red armlets',
#      'COLOURS_FILENAME': 'c20230617utt/00870732.jpg',
#      'FORECASTPRICE_DENOMINATOR': '1',
#      'DAMSIRE_NAME': 'Presenting',
#      'WEIGHT_VALUE': '163',
#      'SEX_TYPE': 'M',
#      'DAYS_SINCE_LAST_RUN': '26',
#      'WEARING': 'Visor',
#      'OWNER_NAME': 'J And J McAndrew',
#      'DAM_YEAR_BORN': '0',
#      'SIRE_BRED': 'FRA',
#      'JOCKEY_NAME': 'Tom Cannon',
#      'DAM_BRED': 'IRL',
#      'ADJUSTED_RATING': None,
#      'runnerId': '51418306',
#      'CLOTH_NUMBER': '3',
#      'SIRE_YEAR_BORN': '2010',
#      'TRAINER_NAME': 'L Wadham',
#      'COLOUR_TYPE': 'b',
#      'AGE': '6',
#      'DAMSIRE_BRED': 'GBR',
#      'JOCKEY_CLAIM': '0',
#      'FORM': 'PP2P8-4',
#      'FORECASTPRICE_NUMERATOR': '7',
#      'BRED': None,
#      'DAM_NAME': 'Lace Parasol',
#      'DAMSIRE_YEAR_BORN': '1992',
#      'STALL_DRAW': None,
#      'WEIGHT_UNITS': 'pounds'}},
#    {'selectionId': 28244473,
#     'runnerName': 'Fraterculus',
#     'handicap': 0.0,
#     'sortPriority': 6,
#     'metadata': {'SIRE_NAME': 'Teofilo',
#      'CLOTH_NUMBER_ALPHA': '7',
#      'OFFICIAL_RATING': None,
#      'COLOURS_DESCRIPTION': 'Light blue, dark blue stars, white sleeves, light blue stars, light blue cap, dark blue star',
#      'COLOURS_FILENAME': 'c20230617utt/00874026.jpg',
#      'FORECASTPRICE_DENOMINATOR': '1',
#      'DAMSIRE_NAME': 'Anabaa',
#      'WEIGHT_VALUE': '142',
#      'SEX_TYPE': 'G',
#      'DAYS_SINCE_LAST_RUN': '1084',
#      'WEARING': 'Tongue strap,Cheek pieces',
#      'OWNER_NAME': 'Mr Stuart Coxon',
#      'DAM_YEAR_BORN': '2008',
#      'SIRE_BRED': 'IRL',
#      'JOCKEY_NAME': 'Toby Wynne',
#      'DAM_BRED': 'USA',
#      'ADJUSTED_RATING': None,
#      'runnerId': '28244473',
#      'CLOTH_NUMBER': '7',
#      'SIRE_YEAR_BORN': '2004',
#      'TRAINER_NAME': 'O Greenall & J Guerriero',
#      'COLOUR_TYPE': 'ch',
#      'AGE': '6',
#      'DAMSIRE_BRED': 'USA',
#      'JOCKEY_CLAIM': '5',
#      'FORM': '4687U-4',
#      'FORECASTPRICE_NUMERATOR': '8',
#      'BRED': None,
#      'DAM_NAME': 'Sanaara',
#      'DAMSIRE_YEAR_BORN': '1992',
#      'STALL_DRAW': None,
#      'WEIGHT_UNITS': 'pounds'}},
#    {'selectionId': 35913004,
#     'runnerName': 'Eightytwo Team',
#     'handicap': 0.0,
#     'sortPriority': 7,
#     'metadata': {'SIRE_NAME': 'Mahler',
#      'CLOTH_NUMBER_ALPHA': '5',
#      'OFFICIAL_RATING': None,
#      'COLOURS_DESCRIPTION': 'Orange, black star, black and orange chevrons on sleeves, black cap, orange star',
#      'COLOURS_FILENAME': 'c20230617utt/00844457.jpg',
#      'FORECASTPRICE_DENOMINATOR': '1',
#      'DAMSIRE_NAME': 'Overbury',
#      'WEIGHT_VALUE': '149',
#      'SEX_TYPE': 'M',
#      'DAYS_SINCE_LAST_RUN': '19',
#      'WEARING': 'Cheek pieces',
#      'OWNER_NAME': 'Mr Robert P Clarke',
#      'DAM_YEAR_BORN': '2003',
#      'SIRE_BRED': 'GBR',
#      'JOCKEY_NAME': 'C J Todd',
#      'DAM_BRED': 'GBR',
#      'ADJUSTED_RATING': None,
#      'runnerId': '35913004',
#      'CLOTH_NUMBER': '5',
#      'SIRE_YEAR_BORN': '1990',
#      'TRAINER_NAME': 'C Ellam',
#      'COLOUR_TYPE': 'b',
#      'AGE': '7',
#      'DAMSIRE_BRED': 'IRL',
#      'JOCKEY_CLAIM': '0',
#      'FORM': 'P3PP-U3',
#      'FORECASTPRICE_NUMERATOR': '10',
#      'BRED': None,
#      'DAM_NAME': 'Lady Hillingdon',
#      'DAMSIRE_YEAR_BORN': '1991',
#      'STALL_DRAW': None,
#      'WEIGHT_UNITS': 'pounds'}}]}]

# %%
# explore the results for one runner:

marketCatelogue[0]['runners'][1]
# Out:
# {'selectionId': 55720954,
#  'runnerName': 'Glorious Mist',
#  'handicap': 0.0,
#  'sortPriority': 2,
#  'metadata': {'SIRE_NAME': 'Fame And Glory',
#   'CLOTH_NUMBER_ALPHA': '4',
#   'OFFICIAL_RATING': '0',
#   'COLOURS_DESCRIPTION': 'Yellow, black star, black and yellow halved sleeves, yellow and black quartered cap',
#   'COLOURS_FILENAME': 'c20230616fon/00865785.jpg',
#   'FORECASTPRICE_DENOMINATOR': '4',
#   'DAMSIRE_NAME': 'Kings Theatre',
#   'WEIGHT_VALUE': '148',
#   'SEX_TYPE': 'M',
#   'DAYS_SINCE_LAST_RUN': '19',
#   'WEARING': None,
#   'OWNER_NAME': 'Mrs Elizabeth Anne Elliott',
#   'DAM_YEAR_BORN': '2008',
#   'SIRE_BRED': 'GBR',
#   'JOCKEY_NAME': 'Luke Scott',
#   'DAM_BRED': 'IRL',
#   'ADJUSTED_RATING': None,
#   'runnerId': '55720954',
#   'CLOTH_NUMBER': '4',
#   'SIRE_YEAR_BORN': '1985',
#   'TRAINER_NAME': 'P Butler',
#   'COLOUR_TYPE': 'b',
#   'AGE': '6',
#   'DAMSIRE_BRED': 'IRL',
#   'JOCKEY_CLAIM': '7',
#   'FORM': '42RP-62',
#   'FORECASTPRICE_NUMERATOR': '9',
#   'BRED': None,
#   'DAM_NAME': 'Amazon Mist',
#   'DAMSIRE_YEAR_BORN': '1991',
#   'STALL_DRAW': None,
#   'WEIGHT_UNITS': 'pounds'}}

# %%
headers
# Out:
# {'X-Application': '6CqiPUMcgYJjnhbh',
#  'X-Authentication': 'xOiGfzTUIFhEUr8LD/760kINOy/QmtPgFWTzVJWEZo4=',
#  'content-type': 'application/json'}

# %%
import time

d = {'Time': [], 'Price':[], 'Size': []}
odds_horse = pd.DataFrame(data=d)

loop_count =   # Number of times to execute the loop
loop_delay = 20  # Delay between each loop in seconds

for i in range(loop_count):
    # Your code here
    print(f"Loop iteration {i + 1}")
    
    # Wait for the specified delay
    time.sleep(loop_delay)

priceProjection = '["EX_BEST_OFFERS"]'
marketId = str(marketCatelogue[0]['marketId'])
selectionId = str(marketCatelogue[0]['runners'][0]['selectionId'])

user_req='{"jsonrpc": "2.0", "method": "SportsAPING/v1.0/listMarketCatalogue",\
           "params": {"filter":{"eventTypeIds":'+eventTypeID+',"marketTypeCodes":'+marketTypeCode+',\
           "inPlayOnly":'+inplay+', "marketCountries":'+countryCode+',  \
           "marketStartTime":{"from":"'+MarketStartTime+'", "to":"'+MarketEndTime+'"}},\
           "sort":"'+sortType+'", "maxResults":"'+maxResults+'", "marketProjection":["'+Metadata+'"]}, "id": 1}'


price_req = '{"jsonrpc": "2.0", "method": "SportsAPING/v1.0/listRunnerBook", "params": {"locale":"en",\
            "marketId":"'+marketId+'", "selectionId":"'+selectionId+'", '\
            '"priceProjection":{"priceData":'+priceProjection+'},"orderProjection":"ALL"},"id":1}'
req = urllib.request.Request(bet_url, data=price_req.encode('utf-8'), headers=headers)
price_response= urllib.request.urlopen(req)
price_jsonResponse = price_response.read()
price_pkg = price_jsonResponse.decode('utf-8')
price_result = json.loads(price_pkg)
price_result['result'][0]
# Out:
# {'marketId': '1.215231863',
#  'isMarketDataDelayed': True,
#  'status': 'OPEN',
#  'betDelay': 0,
#  'bspReconciled': False,
#  'complete': True,
#  'inplay': False,
#  'numberOfWinners': 1,
#  'numberOfRunners': 5,
#  'numberOfActiveRunners': 4,
#  'lastMatchTime': '2023-06-16T16:20:00.269Z',
#  'totalMatched': 7640.6,
#  'totalAvailable': 216859.1,
#  'crossMatching': True,
#  'runnersVoidable': False,
#  'version': 5296961494,
#  'runners': [{'selectionId': 36643074,
#    'handicap': 0.0,
#    'status': 'ACTIVE',
#    'adjustmentFactor': 35.378,
#    'lastPriceTraded': 2.62,
#    'totalMatched': 0.0,
#    'ex': {'availableToBack': [{'price': 2.58, 'size': 30.78},
#      {'price': 2.56, 'size': 51.53},
#      {'price': 2.54, 'size': 36.77}],
#     'availableToLay': [{'price': 2.7, 'size': 17.19},
#      {'price': 2.72, 'size': 15.58},
#      {'price': 2.76, 'size': 38.29}],
#     'tradedVolume': []}}]}

# %%
def BestHorseForm():
    
    Rating = float(0)
    Index = float(0)
    FormRatingAvg = float(100)
    FormRatingList = []
    horsename = []
    selectionID=[]
    
    eventTypeID = '["7"]' #ID for Horse Racing
    countryCode= '["GB","IE"]' #Country Codes. Betfair use Alpha-2 Codes under ISO 3166-1
    marketTypeCode='["WIN"]' #Market Type
    MarketStartTime= datetime.datetime.now().strftime('%Y-%m-%dT%H:%M:%SZ') #Event Start and End times
    MarketEndTime = (datetime.datetime.now() + datetime.timedelta(hours=0.5))
    MarketEndTime = MarketEndTime.strftime('%Y-%m-%dT%H:%M:%SZ')
    maxResults = str(1000)
    sortType = 'FIRST_TO_START' #Sorts the Output
    Metadata = 'RUNNER_METADATA' #Provides metadata
    inplay = 'false' #still to run
    priceProjection = '["EX_BEST_OFFERS"]'#Best odds
    
    #Create an empty dataframe
    d = {'Horse Name': [], 'Form':[], 'Race': [], 'Odds':[]}
    Results = pd.DataFrame(data=d)
    
    # my_username = "log_runner"
    # my_password = "mxh.qtz7mub7mdw@KVX"
    # my_app_key = "6CqiPUMcgYJjnhbh"
    # my_cert = './../default_app.crt'
    # my_key = './../bf_key_rsa.pem'

    # payload = 'username=' + my_username + '&password=' + my_password
    # headers = {'X-Application': my_app_key, 'Content-Type': 'application/x-www-form-urlencoded'}
    # bet_url="https://api.betfair.com/exchange/betting/json-rpc/v1"
    # resp = requests.post('https://identitysso-cert.betfair.com/api/certlogin',data=payload,cert=(my_cert,my_key),headers=headers)
    # resp_json=resp.json()
    # SSOID = resp_json['sessionToken']
    
    headers = {'X-Application': my_app_key, 'X-Authentication': SSOID, 'content-type': 'application/json'}
    
    user_req='{"jsonrpc": "2.0", "method": "SportsAPING/v1.0/listMarketCatalogue",\
           "params": {"filter":{"eventTypeIds":'+eventTypeID+',"marketTypeCodes":'+marketTypeCode+',\
           "inPlayOnly":'+inplay+', "marketCountries":'+countryCode+',\
           "marketStartTime":{"from":"'+MarketStartTime+'", "to":"'+MarketEndTime+'"}},\
           "sort":"'+sortType+'", "maxResults":"'+maxResults+'", "marketProjection":["'+Metadata+'"]}, "id": 1}'

    req = urllib.request.Request(bet_url, data=user_req.encode('utf-8'), headers=headers)
    response= urllib.request.urlopen(req)
    jsonResponse = response.read()
    pkg = jsonResponse.decode('utf-8')
    result = json.loads(pkg) 
    marketCatelogue = result['result']
    

    for x in range(len(marketCatelogue)):
        for w in range(len(marketCatelogue[x]['runners'])):
            runnerform = marketCatelogue[x]['runners'][w]['metadata']['FORM']
            if runnerform is None:
                runnerform = 'e'
            
            runnerformList = list(runnerform)
            
            for Entry in runnerformList:
                if Entry == 'R':#refusal to jump hurdle
                    Rating = float(Rating) + float(5)
                    Index = Index + 1
                elif Entry == 'e':#First Race
                    Rating = float(Rating) + float(10)
                    Index = Index + 1
                elif Entry == '0':#finished higher than 9th
                    Rating = float(Rating) + float(10)
                    Index = Index + 1
                elif Entry == 'F':#fell
                    Rating = float(Rating) + float(5)
                    Index = Index + 1
                elif Entry == 'U':#unseated rider
                    Rating = float(Rating) + float(3)
                    Index = Index + 1
                elif Entry == 'x':#horse has not started in a race for 3 months or more
                    Rating = float(Rating) + float(3)
                    Index = Index + 1
                elif Entry == 'C':#horse has won before at this same race distance and at this same track.
                    Rating = float(Rating) + float(.5)
                    Index = Index + 1
                elif Entry == 'B':#horse started favorite at it's last start, but it did not win
                    Rating = float(Rating) + float(3.5)
                    Index = Index + 1
                elif Entry == '/':#represents two seasons ago
                    Rating = float(Rating) + float(8)
                    Index = Index + 1
                elif Entry == '-':#represents one season ago
                    Rating = float(Rating) + float(4)
                    Index = Index + 1
                elif Entry == 'P':#pulled up by jockey
                    Rating = float(Rating) + float(4)
                    Index = Index + 1
                else:
                    try:
                        Rating = float(Rating) + float(Entry)
                    except ValueError:
                        Rating = float(Rating)
                    Index = Index + 1
                                                                
            rating = float(Rating)/float(Index)
            FormRatingList.append(rating)
                
        for t in range(len(FormRatingList)):
            if FormRatingList[t] < FormRatingAvg:
                FormRatingAvg = FormRatingList[t]
                horsename.append(marketCatelogue[x]['runners'][t]['runnerName'])
                selectionID.append(marketCatelogue[x]['runners'][t]['selectionId'])

        price_req = '{"jsonrpc": "2.0", "method": "SportsAPING/v1.0/listRunnerBook", "params": {"locale":"en", \
                    "marketId":"'+str(marketCatelogue[x]['marketId'])+'",\
                    "selectionId":"'+str(selectionID[-1])+'",\
                    "priceProjection":{"priceData":'+priceProjection+'},"orderProjection":"ALL"},"id":1}'
       
        req = urllib.request.Request(bet_url, data=price_req.encode('utf-8'), headers=headers)
        price_response= urllib.request.urlopen(req)
        price_jsonResponse = price_response.read()
        price_pkg = price_jsonResponse.decode('utf-8')
        price_result = json.loads(price_pkg) 
        
        horse_name = str(horsename[-1])
        horse_rating = str(int(FormRatingAvg))
        race_name = str(marketCatelogue[x]['marketName'])
        try:
            horse_price = str(price_result['result'][0]['runners'][0]['ex']['availableToBack'][0]['price'])
        except IndexError:
            horse_price = '-1'
        
        new_row = {'Horse Name':horse_name, 'Form':horse_rating, 'Race':race_name, 'Odds':horse_price}
        # Results = Results.append({'Horse Name':str(horsename[-1]), 'Form':str(int(FormRatingAvg)), 'Race':str(marketCatelogue[x]['marketName']), 'Odds':str(price_result['result'][0]['runners'][0]['ex']['availableToBack'][0]['price'])}, ignore_index=True)
        # Results = Results.append(new_data, ignore_index=True)
        Results.loc[len(Results)] = new_row
        
        Rating = float(0)
        Index = float(0)
        FormRatingAvg = float(100)
        FormRatingList.clear()
        horsename.clear()
        selectionID.clear
                 
    return Results

# %%
BestHorseForm()
# Out:
#          Horse Name Form               Race Odds
# 0  Ice Cold In Alex    5            6f Hcap  4.6
# 1      Jet Of Magic    3  3m1f Nov Hcap Chs  5.0
# 2     Final Gesture    3         1m4f Grp 3  5.0
# 3            Vaynor    4          1m6f Hcap  8.6
